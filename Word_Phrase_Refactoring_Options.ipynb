# %%
# !pip install scattertext

# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting scattertext
#   Downloading https://files.pythonhosted.org/packages/e0/6a/d2b2af772934a946cbebb47cb068b4631ed437a264d9cfc7ef5761f95e00/scattertext-0.0.2.56-py3-none-any.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 4.1MB/s
# Collecting mock
#   Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.25.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.21.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.12.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.17.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->scattertext) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->scattertext) (2.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->scattertext) (0.14.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels->scattertext) (0.5.1)
# Installing collected packages: mock, scattertext
# Successfully installed mock-3.0.5 scattertext-0.0.2.56
# Collecting flask_cors
#   Downloading https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Requirement already satisfied: Six in /usr/local/lib/python3.6/dist-packages (from flask_cors) (1.12.0)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.6/dist-packages (from flask_cors) (1.1.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (0.16.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (2.10.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.9->flask_cors) (1.1.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.8
# Collecting python-decouple
#   Downloading https://files.pythonhosted.org/packages/c7/82/dd20cdca396f58be86c6e710a3958f4a34ca98c5dd3989ee978b6cb9f97e/python-decouple-3.3.tar.gz
# Building wheels for collected packages: python-decouple
#   Building wheel for python-decouple (setup.py) ... done
#   Created wheel for python-decouple: filename=python_decouple-3.3-cp36-none-any.whl size=9024 sha256=e84b41dd65dc04c702894918f94029683f7e1454a85c77a79e5a48550378873d
#   Stored in directory: /root/.cache/pip/wheels/f4/9b/79/5eec9ea205382552b014e749cb8a2b4ce0d6836a6f4db5ac0c
# Successfully built python-decouple
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.3
# Collecting spacy
#   Downloading https://files.pythonhosted.org/packages/47/13/80ad28ef7a16e2a86d16d73e28588be5f1085afd3e85e4b9b912bd700e8a/spacy-2.2.3-cp36-cp36m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 5.0MB/s
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/db/6b/e07fad36913879757c90ba03d6fb7f406f7279e11dcefc105ee562de63ea/preshed-3.0.2-cp36-cp36m-manylinux1_x86_64.whl (119kB)
#      |████████████████████████████████| 122kB 55.8MB/s
# Collecting blis<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/41/19/f95c75562d18eb27219df3a3590b911e78d131b68466ad79fdf5847eaac4/blis-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 54.8MB/s
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading https://files.pythonhosted.org/packages/07/59/6bb553bc9a5f072d3cd479fc939fea0f6f682892f1f5cff98de5c9b615bb/thinc-7.3.1-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 47.4MB/s
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.0)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading https://files.pythonhosted.org/packages/4b/4c/0e0fa8b1e193c1e09a6b72807ff4ca17c78f68f0c0f4459bc8043c66d649/catalogue-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (42.0.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.21.0)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.2)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.9.6)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.17.4)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.4.0,>=7.3.0->spacy) (4.28.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.3.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (0.6.0)
# Requirement already satisfied, skipping upgrade: more-itertools in /usr/local/lib/python3.6/dist-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (8.0.2)
# Installing collected packages: preshed, blis, thinc, catalogue, spacy
#   Found existing installation: preshed 2.0.1
#     Uninstalling preshed-2.0.1:
#       Successfully uninstalled preshed-2.0.1
#   Found existing installation: blis 0.2.4
#     Uninstalling blis-0.2.4:
#       Successfully uninstalled blis-0.2.4
#   Found existing installation: thinc 7.0.8
#     Uninstalling thinc-7.0.8:
#       Successfully uninstalled thinc-7.0.8
#   Found existing installation: spacy 2.1.9
#     Uninstalling spacy-2.1.9:
#       Successfully uninstalled spacy-2.1.9
# Successfully installed blis-0.4.1 catalogue-0.2.0 preshed-3.0.2 spacy-2.2.3 thinc-7.3.1
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0MB)
#      |████████████████████████████████| 12.0MB 815kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.3.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.2.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.21.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (42.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.17.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.28.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.6/dist-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (8.0.2)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.5-cp36-none-any.whl size=12011741 sha256=9bd89416eef102249ac06552eff10cbca799bcd23e07a0f0c6bfb7aea578de36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-29lffpxc/wheels/6a/47/fb/6b5a0b8906d8e8779246c67d4658fd8a544d4a03a75520197a
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.1.0
#     Uninstalling en-core-web-sm-2.1.0:
#       Successfully uninstalled en-core-web-sm-2.1.0
# Successfully installed en-core-web-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
from flask import Flask, render_template, request, jsonify
import json
import warnings
import pandas as pd
import spacy
import scattertext as st
from lxml import html
from requests import Session
from concurrent.futures import ThreadPoolExecutor as Executor
import requests
# from flask_cors import CORS
# from decouple import config
import re
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.max_colwidth', 1000)
nlp = spacy.load("en_core_web_sm")#if you run into problems here, 'Restart Runtime' and run all, it might fix things.
base_url = "https://www.yelp.com/biz/" 
api_url = "/review_feed?sort_by=date_desc&start="
bid = 'Rc1lxc5lSKJYd162JHNMfQ'

class Scraper():
    def __init__(self):
        self.data = pd.DataFrame()

    def get_data(self, n, bid=bid):
        with Session() as s:
            with s.get(base_url+bid+api_url+str(n*20)) as resp: #makes an http get request to given url and returns response as json
                r = json.loads(resp.content) #converts json response into a dictionary
                _html = html.fromstring(r['review_list']) #loads from dictionary

                dates = _html.xpath("//div[@class='review-content']/descendant::span[@class='rating-qualifier']/text()")
                reviews = [el.text for el in _html.xpath("//div[@class='review-content']/p")]
                ratings = _html.xpath("//div[@class='review-content']/descendant::div[@class='biz-rating__stars']/div/@title")

                df = pd.DataFrame([dates, reviews, ratings]).T

                self.data = pd.concat([self.data,df])

    def scrape(self): #makes it faster
        # multithreaded looping
        with Executor(max_workers=40) as e:
            list(e.map(self.get_data, range(10)))

s = Scraper()
s.scrape()
df = s.data


def customtokensize(text):
    return re.findall("[\w']+", str(text))

df['tokenized_text'] = df[1].apply(customtokensize)
# stopwords = ['and','was','were','had','check-in','=','= =','u','want', 'u want', 'cuz','him',"i've",'on', 'her','told','ins', '1 check','I', 'i"m', 'i', ' ', 'it', "it's", 'it.','they', 'the', 'this','its', 'l','they','this',"don't",'the ', ' the', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.',',']

stopwords = [',','"','!','-','&','?']

def filter_stopwords(text):
  nonstopwords = []
  for i in text:
    if i not in stopwords:
      nonstopwords.append(i)
  return nonstopwords
df['tokenized_text'] = df['tokenized_text'].apply(filter_stopwords)
df['parts_of_speech_reference'] = df['tokenized_text'].apply(filter_stopwords)
df['parts_of_speech_reference'] = df['parts_of_speech_reference'].str.join(' ')
# df['parts_of_speech_reference'] = df['tokenized_text'].str.join(' ')
df.head(1)
# Out:
#                            0  \
# 0  \n        10/2/2019\n
#
#                                                                                                                                                                                                                                                                 1  \
# 0  Came here with my mom before a broadway show for her bday! The table was approx the width of my big toe but it was super cute and the food was amazing!! Def make a reservation there was a line out the door within the hr of it opening for dinner service!!
#
#                  2  \
# 0  5.0 star rating
#
#                                                                                                                                                                                                                                                                                                    tokenized_text  \
# 0  [Came, here, with, my, mom, before, a, broadway, show, for, her, bday, The, table, was, approx, the, width, of, my, big, toe, but, it, was, super, cute, and, the, food, was, amazing, Def, make, a, reservation, there, was, a, line, out, the, door, within, the, hr, of, it, opening, for, dinner, service]
#
#                                                                                                                                                                                                                                    parts_of_speech_reference
# 0  Came here with my mom before a broadway show for her bday The table was approx the width of my big toe but it was super cute and the food was amazing Def make a reservation there was a line out the door within the hr of it opening for dinner service

# %%
def find_nounchunks(x):
  """noun chunks greater than 2 without stopwords"""
  noun_list = []
  doc = nlp(str(x))
  for chunk in doc.noun_chunks:
    if len(chunk) > 2:
      noun_list.append(chunk)
  return noun_list

df['nounchunk_list'] = df[1].apply(find_nounchunks)
df[[1,'nounchunk_list']].head(1)
# Out:
#                                                                                                                                                                                                                                                                 1  \
# 0  Came here with my mom before a broadway show for her bday! The table was approx the width of my big toe but it was super cute and the food was amazing!! Def make a reservation there was a line out the door within the hr of it opening for dinner service!!
#
#                           nounchunk_list
# 0  [(a, broadway, show), (my, big, toe)]

# %%
def find_words_after_and_before_THE_A_AN(x):
  """find_words_after_and_before_THE"""
  total_lists = []
  doc = nlp(str(x))
  for token in range(len(doc)):
    try:
      word_list1 = []
      if (doc[token].pos_ == 'PRON') or ((doc[token-1].pos_ == 'VERB') and (doc[token].text == 'the')) or ((doc[token-1].pos_ == 'ADV') and (doc[token].text == 'the')) or (doc[token].text == 'The') or (doc[token].text == 'a') or (doc[token].text == 'A') or (doc[token].text == 'an') or (doc[token].text == 'An'):
        word_list1.append(doc[token])
        word_list1.append(doc[token+1])
        word_list1.append(doc[token+2])
        word_list1.append(doc[token+3])
        word_list1.append(doc[token+4])
        word_list1.append(doc[token+5])
        word_list1.append(doc[token+6])
        word_list1.append(doc[token+7])
        word_list1.append(doc[token+8])
        word_list1.append(doc[token+9])
        word_list1.append(doc[token+10])
        word_list1.append(doc[token+11])
      if len(word_list1) != 0:
        total_lists.append(word_list1)
    except IndexError or TypeError as e:
      for token in range(len(doc)):
        try:
          word_list2 = []
          if (doc[token].pos_ == 'PRON') or ((doc[token].pos_ == 'the') and (doc[token].pos_ == 'PRON')) or (doc[token].text == 'The') or (doc[token].text == 'a') or (doc[token].text == 'A') or (doc[token].text == 'an') or (doc[token].text == 'An'):
            word_list2.append(doc[token])
            word_list2.append(doc[token+1])
            word_list2.append(doc[token+2])
            word_list2.append(doc[token+3])
            word_list2.append(doc[token+4])
            word_list2.append(doc[token+5])
            word_list2.append(doc[token+6])
            word_list2.append(doc[token+7])
          if (len(word_list2) != 0) and (False for i in word_list2 for i in word_list1) and (False for i in word_list2 for i in total_lists):
            total_lists.append(word_list2) 
        except IndexError or TypeError as e:
          for token in range(len(doc)):
            try:
              word_list3 = []
              if ((doc[token-1].pos_ == 'VERB') and (doc[token].text == 'the')) or ((doc[token-1].pos_ == 'ADV') and (doc[token].text == 'the')):
                word_list3.append(doc[token-1])
                word_list3.append(doc[token])
                word_list3.append(doc[token+1])
                word_list3.append(doc[token+2])
              if (len(word_list3) != 0 ) and (False for i in word_list3 for i in word_list2) and (False for i in word_list3 for i in total_lists):
                total_lists.append(word_list3)
            except IndexError or TypeError as e:
              for token in range(len(doc)):
                try:
                  word_list4 = []
                  if (doc[token].text == 'the') or (doc[token].text == 'a') or (doc[token].text == 'an'):
                    word_list4.append(doc[token])
                    word_list4.append(doc[token+1])
                    word_list4.append(doc[token+2])
                    word_list4.append(doc[token+3])
                  if (len(word_list4) != 0 ) and (False for i in word_list4 for i in word_list3) and (False for i in word_list4 for i in total_lists):
                    total_lists.append(word_list4)
                except IndexError or TypeError as e:
                  pass
  return total_lists

df['words_around_THE_A_AN'] = df['parts_of_speech_reference'].apply(find_words_after_and_before_THE_A_AN)
df[[1,'words_around_THE_A_AN']].head(1)
# Out:
#                                                                                                                                                                                                                                                                 1  \
# 0  Came here with my mom before a broadway show for her bday! The table was approx the width of my big toe but it was super cute and the food was amazing!! Def make a reservation there was a line out the door within the hr of it opening for dinner service!!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            words_around_THE_A_AN
# 0  [[a, broadway, show, for, her, bday, The, table, was, approx, the, width], [The, table, was, approx, the, width, of, my, big, toe, but, it], [the, width, of, my, big, toe, but, it, was, super, cute, and], [it, was, super, cute, and, the, food, was, amazing, Def, make, a], [a, reservation, there, was, a, line, out, the, door, within, the, hr], [there, was, a, line, out, the, door, within, the, hr, of, it], [a, line, out, the, door, within, the, hr, of, it, opening, for], [a, broadway, show, for, her, bday, The, table], [The, table, was, approx, the, width, of, my], [it, was, super, cute, and, the, food, was], [a, reservation, there, was, a, line, out, the], [there, was, a, line, out, the, door, within], [a, line, out, the, door, within, the, hr], [approx, the, width, of]]

# %%
def find_phrases(x):
  long_phrase_list = []
  doc = nlp(str(x))
  for token in range(len(doc)):
    sub_list = []
    try:
      if (doc[token-1].text == 'on') and (doc[token].text == 'a') or (doc[token].text == 'for') or (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'VERB' and doc[token+1].pos_ == 'NOUN') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'ADJ'and doc[token+2].pos_ =='NOUN')or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='VERB'and doc[token+2].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN'and doc[token+2].pos_ =='NOUN'):
        if doc[token-1] not in sub_list and doc[token] not in sub_list and doc[token+1] not in sub_list and doc[token+2] not in sub_list and doc[token+3] not in sub_list:
          sub_list.append(doc[token-1])
          sub_list.append(doc[token])
          sub_list.append(doc[token+1])
          sub_list.append(doc[token+2])
          sub_list.append(doc[token+3])
    except IndexError as e:
      try:
        if (doc[token-1].text == 'on') and (doc[token].text == 'a') or (doc[token].text == 'for') or (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'VERB' and doc[token+1].pos_ == 'NOUN') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'ADJ'and doc[token+2].pos_ =='NOUN')or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='VERB'and doc[token+2].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN'and doc[token+2].pos_ =='NOUN'):
          if doc[token-1] not in sub_list and doc[token] not in sub_list and doc[token+1] not in sub_list and doc[token+2] not in sub_list:
            sub_list.append(doc[token-1])
            sub_list.append(doc[token])
            sub_list.append(doc[token+1])
            sub_list.append(doc[token+2])
      except IndexError as e:
        try:
          if (doc[token-1].text == 'on') and (doc[token].text == 'a') or (doc[token].text == 'for') or (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'VERB' and doc[token+1].pos_ == 'NOUN') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'ADJ'and doc[token+2].pos_ =='NOUN')or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='VERB'and doc[token+2].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN'and doc[token+2].pos_ =='NOUN'):
            if doc[token-1] not in sub_list and doc[token] not in sub_list and doc[token+1] not in sub_list:
              sub_list.append(doc[token-1])
              sub_list.append(doc[token])
              sub_list.append(doc[token+1])
        except IndexError as e:
          try:
            if (doc[token].text == 'on') or (doc[token].text == 'for') or (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'VERB' and doc[token+1].pos_ == 'NOUN') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'ADJ'and doc[token+2].pos_ =='NOUN')or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='VERB'and doc[token+2].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN'and doc[token+2].pos_ =='NOUN'):
              if doc[token] not in sub_list and doc[token+1] not in sub_list:
                sub_list.append(doc[token])
                sub_list.append(doc[token+1])
          except IndexError as e:
            try:
              #captures words at the end of reviews
              if (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token-1].pos_ == 'ADJ'and doc[token].pos_ =='NOUN') or (doc[token-1].pos_ == 'VERB'and doc[token].pos_ =='NOUN')or (doc[token-1].pos_ == 'NOUN'and doc[token].pos_ =='NOUN'):
                if doc[token] not in sub_list and doc[token+1] not in sub_list:
                  sub_list.append(doc[token-1])
                  sub_list.append(doc[token])
            except IndexError as e:
              try:
                #captures words from the start of reviews
                if (doc[token].text == 'food is') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'NOUN' and doc[token+1].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN')or (doc[token].pos_ == 'NOUN'and doc[token+1].pos_ =='NOUN'):
                  if doc[token] not in sub_list and doc[token+1] not in sub_list:
                    sub_list.append(doc[token])
                    sub_list.append(doc[token+1])
              except IndexError as e:
                pass
    if (len(sub_list) != 0) and (sub_list not in long_phrase_list):
      long_phrase_list.append(sub_list)
  return long_phrase_list


df['AdjNouns_NounNouns_Service_Food_For'] = df[1].apply(find_phrases)
df[[1,'nounchunk_list','AdjNouns_NounNouns_Service_Food_For','words_around_THE_A_AN']].sample(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                      1  \
# 13  I went here one night to celebrate my birthday, in January. The place has a classic look with red chairs. It's spacious and intimate with dimly lit light areas. There's also an outside area that is heated so you can do that even in the colder months confortab. Staff was warm and welcoming. Loved the food as well. Had the Shepard's pie and a ceviche dish, both awesome.
#
#                                                                                                                                           nounchunk_list  \
# 13  [(a, classic, look), (dimly, lit, light, areas), (an, outside, area), (the, colder, months, confortab), (the, Shepard, 's, pie), (a, ceviche, dish)]
#
#                                                                                                                                AdjNouns_NounNouns_Service_Food_For  \
# 13  [[a, classic, look, with, red], [with, red, chairs, ., It], [lit, light, areas, ., There], [an, outside, area, that, is], [the, colder, months, confortab, .]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      words_around_THE_A_AN
# 13  [[I, went, here, one, night, to, celebrate, my, birthday, in, January, The], [The, place, has, a, classic, look, with, red, chairs, It, 's, spacious], [a, classic, look, with, red, chairs, It, 's, spacious, and, intimate, with], [It, 's, spacious, and, intimate, with, dimly, lit, light, areas, There, 's], [There, 's, also, an, outside, area, that, is, heated, so, you, can], [an, outside, area, that, is, heated, so, you, can, do, that, even], [you, can, do, that, even, in, the, colder, months, confortab, Staff, was], [the, food, as, well, Had, the, Shepard, 's, pie, and, a, ceviche], [I, went, here, one, night, to, celebrate, my], [The, place, has, a, classic, look, with, red], [a, classic, look, with, red, chairs, It, 's], [It, 's, spacious, and, intimate, with, dimly, lit], [There, 's, also, an, outside, area, that, is], [an, outside, area, that, is, heated, so, you], [you, can, do, that, even, in, the, colder], [Loved, the, food, as]]

# %%
def find_word_segments(x):
  long_phrase_list = []
  doc = nlp(str(x))
  try:
    for token in range(len(doc)):
      sub_list = []
      if (token < (int(len(doc))-5)) and ((doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN'and doc[token+2].pos_ =='NOUN') or (doc[token].text == 'food') or (doc[token].lemma_ == 'order') or (doc[token].text == 'but') or (doc[token].text == 'not') or (doc[token].pos_ == 'VERB' and doc[token+1].pos_ == 'NOUN') or (doc[token-1].pos_ == 'NOUN' and doc[token].pos_ == 'VERB') or (doc[token].lemma_ == 'service') or (doc[token].lemma_ == 'wait') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'VERB'and doc[token+1].pos_ =='NOUN') or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'ADJ'and doc[token+2].pos_ =='NOUN')or (doc[token].pos_ == 'ADJ'and doc[token+1].pos_ =='VERB'and doc[token+2].pos_ =='NOUN')):
        sub_list.append(doc[token])
        sub_list.append(doc[token+1])
        sub_list.append(doc[token+2])
        sub_list.append(doc[token+3])
        sub_list.append(doc[token+4])
        sub_list.append(doc[token+5])
        # sub_list.append(doc[token+6])
      if len(sub_list) != 0:
        long_phrase_list.append(sub_list)
  except IndexError as e:
    pass
  try:
    for token in range(len(doc)):
      sub_list = []
      if (token < (int(len(doc))-5)) and ((doc[token].pos_ == 'PRON') or ((doc[token-1].pos_ == 'VERB') and (doc[token].text == 'the')) or ((doc[token-1].pos_ == 'ADV') and (doc[token].text == 'the')) or (doc[token].text == 'The') or (doc[token].text == 'a') or (doc[token].text == 'A') or (doc[token].text == 'an') or (doc[token].text == 'An')):
        sub_list.append(doc[token])
        sub_list.append(doc[token+1])
        sub_list.append(doc[token+2])
        sub_list.append(doc[token+3])
        sub_list.append(doc[token+4])
        sub_list.append(doc[token+5])
      if len(sub_list) != 0:
        long_phrase_list.append(sub_list)
  except IndexError as e:
    pass
  return long_phrase_list

df['word_segments'] = df[1].apply(find_word_segments)
df[[1,'word_segments']].head(1)
# Out:
#                                                                                                                                                                                                                                                                 1  \
# 0  Came here with my mom before a broadway show for her bday! The table was approx the width of my big toe but it was super cute and the food was amazing!! Def make a reservation there was a line out the door within the hr of it opening for dinner service!!
#
#                                                                                                                                                                                                                                                                                                                                                                                            word_segments
# 0  [[big, toe, but, it, was, super], [but, it, was, super, cute, and], [food, was, amazing, !, !, Def], [a, broadway, show, for, her, bday], [The, table, was, approx, the, width], [the, width, of, my, big, toe], [it, was, super, cute, and, the], [a, reservation, there, was, a, line], [there, was, a, line, out, the], [a, line, out, the, door, within], [it, opening, for, dinner, service, !]]

# %%
df['word_segments_unpacked'] = df['word_segments'].apply(lambda l: [item for sublist in l for item in sublist])
df['word_segments_unpacked'] = df['word_segments_unpacked'].astype(str)
df['word_segments_unpacked'] = df['word_segments_unpacked'].apply(lambda x: ''.join([str(i) for i in x]))
df.head(1)
# Out:
#                            0  \
# 0  \n        10/2/2019\n
#
#                                                                                                                                                                                                                                                                 1  \
# 0  Came here with my mom before a broadway show for her bday! The table was approx the width of my big toe but it was super cute and the food was amazing!! Def make a reservation there was a line out the door within the hr of it opening for dinner service!!
#
#                  2  \
# 0  5.0 star rating
#
#                                                                                                                                                                                                                                                                                                    tokenized_text  \
# 0  [Came, here, with, my, mom, before, a, broadway, show, for, her, bday, The, table, was, approx, the, width, of, my, big, toe, but, it, was, super, cute, and, the, food, was, amazing, Def, make, a, reservation, there, was, a, line, out, the, door, within, the, hr, of, it, opening, for, dinner, service]
#
#                                                                                                                                                                                                                                    parts_of_speech_reference  \
# 0  Came here with my mom before a broadway show for her bday The table was approx the width of my big toe but it was super cute and the food was amazing Def make a reservation there was a line out the door within the hr of it opening for dinner service
#
#                           nounchunk_list  \
# 0  [(a, broadway, show), (my, big, toe)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            words_around_THE_A_AN  \
# 0  [[a, broadway, show, for, her, bday, The, table, was, approx, the, width], [The, table, was, approx, the, width, of, my, big, toe, but, it], [the, width, of, my, big, toe, but, it, was, super, cute, and], [it, was, super, cute, and, the, food, was, amazing, Def, make, a], [a, reservation, there, was, a, line, out, the, door, within, the, hr], [there, was, a, line, out, the, door, within, the, hr, of, it], [a, line, out, the, door, within, the, hr, of, it, opening, for], [a, broadway, show, for, her, bday, The, table], [The, table, was, approx, the, width, of, my], [it, was, super, cute, and, the, food, was], [a, reservation, there, was, a, line, out, the], [there, was, a, line, out, the, door, within], [a, line, out, the, door, within, the, hr], [approx, the, width, of]]
#
#                                                                                                              AdjNouns_NounNouns_Service_Food_For  \
# 0  [[show, for, her, bday, !], [my, big, toe, but, it], [toe, but, it, was, super], [opening, for, dinner, service, !], [dinner, service, !, !]]
#
#                                                                                                                                                                                                                                                                                                                                                                                            word_segments  \
# 0  [[big, toe, but, it, was, super], [but, it, was, super, cute, and], [food, was, amazing, !, !, Def], [a, broadway, show, for, her, bday], [The, table, was, approx, the, width], [the, width, of, my, big, toe], [it, was, super, cute, and, the], [a, reservation, there, was, a, line], [there, was, a, line, out, the], [a, line, out, the, door, within], [it, opening, for, dinner, service, !]]
#
#                                                                                                                                                                                                                                                                                                                                                             word_segments_unpacked
# 0  [big, toe, but, it, was, super, but, it, was, super, cute, and, food, was, amazing, !, !, Def, a, broadway, show, for, her, bday, The, table, was, approx, the, width, the, width, of, my, big, toe, it, was, super, cute, and, the, a, reservation, there, was, a, line, there, was, a, line, out, the, a, line, out, the, door, within, it, opening, for, dinner, service, !]

# %%
phrase_count = df[['word_segments_unpacked', 2]]
import numpy as np

s= phrase_count.apply(lambda x: pd.Series(x['word_segments_unpacked']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'word_segments_unpacked'

phrase_count = phrase_count.drop('word_segments_unpacked', axis=1).join(s)
phrase_count.head(1)
# Out:
#                  2  \
# 0  5.0 star rating
#
#                                                                                                                                                                                                                                                                                                                                                             word_segments_unpacked
# 0  [big, toe, but, it, was, super, but, it, was, super, cute, and, food, was, amazing, !, !, Def, a, broadway, show, for, her, bday, The, table, was, approx, the, width, the, width, of, my, big, toe, it, was, super, cute, and, the, a, reservation, there, was, a, line, there, was, a, line, out, the, a, line, out, the, door, within, it, opening, for, dinner, service, !]

# %%
phrase_count = pd.DataFrame(df['word_segments_unpacked'].str.split(',').tolist(), index=df[2]).stack()
phrase_count = phrase_count.reset_index()[[0, 2]] # var1 variable is currently labeled 0
phrase_count.columns = ['word_segments_unpacked', 'ratings'] # renaming var1
phrase_count = phrase_count.reset_index(drop=False)

# x = ''
# replaceDict = {'to' : '', '!]' : '', '-' : '' }    
# stopwords = ['to','We','had','.',"'re",'it','or','he','she','we','us','how','went','no',"'d",'"','of','has','a','by','bit','thing','NaN','place',' ','on','so','ok','i','and','they','None','was','you',"'ve",'did',"'d",'be','and','but','is','as','a','b','c','d','e','f','g','u','it','!','&','you','has','-','None',':','and','had','was','him','so','my',' ','did','would','on','her','him','it','is','by','bit','thing','NaN','place','[',']','while','check-in','=','= =','want', 'good','husband', 'want','love','something','your','they','your','cuz','him',"i've",'her','told', '1 check', 'i"m', "it's",'they', ' the','the ',' ', 'this','its','they','this',"don't",'the',',', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.']
# def filter_stopwords(text):
#   for i in str(text):
#     if i not in stopwords:
#       return str(text)

# phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].map(filter_stopwords)
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.replace('[','')
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.replace(']','')
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.replace('-','')
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.replace('.','')
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.replace(' ','')
phrase_count['word_segments_unpacked'] = phrase_count['word_segments_unpacked'].str.lower()
# phrase_count = phrase_count[phrase_count['word_segments_unpacked']!=i for i in stopwords]

stopwords = ['from','first','here','only','put','where','got','sure','definitely','food','yet','our','go','since','really','very','two',"n't",'with','if',"'s",'which','came','all','me','(',')','makes','make','were','immediately','get','been','ahead','also','that','one','have','see','what','to','we','had','.',"'re",'it','or','he','she','we','us','how','went','no','"','of','has','by','bit','thing','place','so','ok','and','they','none','was','you',"'ve",'did','be','and','but','is','as','&','you','has','-',':','and','had','was','him','so','my','did','would','her','him','it','is','by','bit','thing','place','[',']','while','check-in','=','= =','want', 'good','husband', 'want','love','something','your','they','your','cuz','him',"i've",'her','told', 'check', 'i"m', "it's",'they', 'this','its','they','this',"don't",'the',',', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.']
def filter_stopwords(text):
  for i in str(text):
    if i not in stopwords:
      return str(text)

phrase_count = phrase_count[~phrase_count['word_segments_unpacked'].isin(stopwords)]#if item in stopwords list partially matches, delete

#full matches
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='i']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='a']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='an']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='am']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='at']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='are']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='in']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='on']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='for']
phrase_count = phrase_count[phrase_count['word_segments_unpacked']!='']
phrase_count.sample(1)
# Out:
#        index word_segments_unpacked          ratings
# 10376  10376                  other  4.0 star rating

# %%
#test values
phrase_count.iloc[4085]['word_segments_unpacked']
# Out:
# '24'

# %%
# phrase_count.tail(188)

# %%
phrase_count_pivot = pd.pivot_table(phrase_count, index='word_segments_unpacked', columns='ratings', aggfunc='count', fill_value=0)
phrase_count_pivot
phrase_count_pivot.sort_values(by=('index','1.0 star rating'), ascending=False)
# Out:
#                                  index                                  \
# ratings                1.0 star rating 2.0 star rating 3.0 star rating
# word_segments_unpacked
# service                             14              13              14
# order                               13               4               1
# wait                                10               2               2
# not                                  8              24              26
#                                      7              12              12
# ...                                ...             ...             ...
# forward                              0               0               0
# fortunately                          0               0               0
# forgot                               0               0               1
# forever                              0               0               2
#                                      0               1               0
#
#
# ratings                4.0 star rating 5.0 star rating
# word_segments_unpacked
# service                             31              49
# order                                7               9
# wait                                 5               7
# not                                 22              18
#                                     15              26
# ...                                ...             ...
# forward                              0               1
# fortunately                          0               2
# forgot                               0               0
# forever                              3               0
#                                      0               0
#
# [1338 rows x 5 columns]

# %%
phrase_count_pivot.columns = [''.join(col).strip() for col in phrase_count_pivot.columns.values]
phrase_count_pivot = pd.DataFrame(phrase_count_pivot.to_records())
phrase_count_pivot
# Out:
#      word_segments_unpacked  index1.0 star rating  index2.0 star rating  \
# 0                         $                     0                     1
# 1                        'd                     0                     0
# 2                       'll                     0                     0
# 3                        'm                     1                     0
# 4                         +                     0                     0
# ...                     ...                   ...                   ...
# 1333                  yummy                     0                     0
# 1334                   zone                     0                     0
# 1335               zucchini                     0                     0
# 1336                                            7                    12
# 1337                                            0                     1
#
#       index3.0 star rating  index4.0 star rating  index5.0 star rating
# 0                        4                     7                     1
# 1                        2                     2                     3
# 2                        0                     3                     0
# 3                        2                     7                     3
# 4                        0                     1                     0
# ...                    ...                   ...                   ...
# 1333                     0                     0                     3
# 1334                     0                     1                     0
# 1335                     0                     1                     1
# 1336                    12                    15                    26
# 1337                     0                     0                     0
#
# [1338 rows x 6 columns]

# %%
def get_rating_scores(x):

# %%
phrase_count_pivot.sort_values(by=('index','1.0 star rating'), ascending=False)
# Out:
#                                  index                                  \
# ratings                1.0 star rating 2.0 star rating 3.0 star rating
# word_segments_unpacked
#  was                                33              29              58
#  and                                31              25              50
#  it                                 28              12              35
#  to                                 26              17              36
#  we                                 22              40              31
# ...                                ...             ...             ...
#  happy                               0               0               1
#  happen                              0               0               1
#  hang                                0               0               0
#  hands                               0               0               0
# yummy                                0               0               0
#
#
# ratings                4.0 star rating 5.0 star rating
# word_segments_unpacked
#  was                                82             148
#  and                               129             191
#  it                                 69             100
#  to                                 70              62
#  we                                 47              96
# ...                                ...             ...
#  happy                               2               1
#  happen                              0               0
#  hang                                1               0
#  hands                               1               0
# yummy                                0               1
#
# [1464 rows x 5 columns]

# %%
phrase_count_pivot.sort_values(by=('index','5.0 star rating'), ascending=True)
# Out:
#                                  index                                  \
# ratings                1.0 star rating 2.0 star rating 3.0 star rating
# word_segments_unpacked
#  starters                            0               1               0
#  serving                             0               0               3
#  served                              5               0               0
#  sense                               0               0               0
#  send                                0               0               0
# ...                                ...             ...             ...
#  we                                 22              40              31
#  it                                 28              12              35
#  food                               18              19              19
#  was                                33              29              58
#  and                                31              25              50
#
#
# ratings                4.0 star rating 5.0 star rating
# word_segments_unpacked
#  starters                            0               0
#  serving                             2               0
#  served                              0               0
#  sense                               4               0
#  send                                1               0
# ...                                ...             ...
#  we                                 47              96
#  it                                 69             100
#  food                               45             117
#  was                                82             148
#  and                               129             191
#
# [1464 rows x 5 columns]

# %%
phrase_count_pivot.sort_values(phrase_count_pivot.columns.tolist()).sort_index(level=1, ascending=False, 
                                                        sort_remaining=False)
# Out:
#                                  index                                  \
# ratings                1.0 star rating 2.0 star rating 3.0 star rating
# word_segments_unpacked
# yummy                                0               0               0
# yelp                                 0               0               1
# worst                                1               0               0
# wonderful                            0               0               0
# wait                                 0               0               0
# ...                                ...             ...             ...
#  're                                 0               0               0
#  'm                                  1               0               2
#  'll                                 0               0               0
#  'd                                  0               0               2
#  $                                   0               1               4
#
#
# ratings                4.0 star rating 5.0 star rating
# word_segments_unpacked
# yummy                                0               1
# yelp                                 0               0
# worst                                0               0
# wonderful                            1               2
# wait                                 2               0
# ...                                ...             ...
#  're                                 3               1
#  'm                                  7               3
#  'll                                 3               0
#  'd                                  2               3
#  $                                   7               1
#
# [1464 rows x 5 columns]

# %%
corpus = st.CorpusFromPandas(df, 
                          category_col=2, 
                          text_col='word_segments_unpacked',
                          nlp=nlp).build()

term_freq_df = corpus.get_term_freq_df()
term_freq_df['highratingscore'] = corpus.get_scaled_f_scores('5.0 star rating')

term_freq_df['poorratingscore'] = corpus.get_scaled_f_scores('1.0 star rating')
dh = term_freq_df.sort_values(by= 'highratingscore', ascending = False)
dh = dh[['highratingscore', 'poorratingscore']]
dh = dh.reset_index(drop=False)
dh = dh.rename(columns={'highratingscore':'score'})
dh = dh.drop(columns='poorratingscore')
dh.head()
# Out:
#         term     score
# 0  cocktails  1.000000
# 1  was great  0.993830
# 2    food is  0.981038
# 3         by  0.979595
# 4      loved  0.973645

# %%
def extract_adj_noun_verb(x):
  doc = nlp(str(x))
  for token in doc:
    if token.pos_ == 'NOUN':
      return token.text

dh['term']= dh['term'].apply(extract_adj_noun_verb)

stopwords = ['a','by','bit','thing','NaN','place']
def filter_stopwords(text):
  try:
    for i in text:
      if i not in stopwords:
        return text
  except TypeError as e:
    pass

dh['term'] = dh['term'].apply(filter_stopwords)
dh = dh[dh['term'].notnull()]#create a new dataframe with only terms that are nouns
dh = dh.groupby(['term']).agg('min')
dh.tail()
# Out:
#               score
# term
# yelp       0.532899
# yelpers    0.500000
# yesterday  0.532899
# zone       0.500000
# zucchini   0.500000

# %%
dh = dh.reset_index(drop=False)

# %%
dh = dh.sort_values(by = 'score', ascending=False)
dh.tail(20)
# Out:
#          term     score
# 126      deal  0.281153
# 203     fries  0.281153
# 401    return  0.281153
# 298   minutes  0.280490
# 416  scallops  0.262622
# 355    plates  0.245336
# 77      check  0.245336
# 199      food  0.245336
# 93   cocktail  0.227305
# 202   friends  0.227305
# 495     thing  0.227305
# 81    chicken  0.211565
# 192       fix  0.211048
# 328    option  0.195085
# 39        bit  0.181575
# 434   service  0.179652
# 352     place  0.179652
# 278      love  0.152259
# 285      meal  0.145691
# 330     order  0.065857

# %%
dh['term'].iloc[-1]
# Out:
# 'order'

# %%
#find where the worst terms appear in the review word segments and extract that word phrase to give context
worst_term = df[df['word_segments_unpacked'].str.contains(dh['term'].iloc[-1])]
worst_term = worst_term.sort_values(by=2, ascending=True)
worst_term.head(1)
# Out:
#                            0  \
# 1  \n        8/17/2019\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1  \
# 1  This is one of the worst restaurants I have been to.  Myself and two friends had a reservation for 1145 as we had theater tickets for a 200 show .  When I entered the restaurant I was greeted by a woman who had a scowl on her face.  Once my friends arrived we were seated in a booth.  It took at least ten to fifteen minutes before someone came to take our drink orders  our drinks were delivered with minimal taste and minimal alcohol.  I ordered a seltzer with pomegranate juice and I got seltzer with maybe a splash of cranberry.  Our food arrived forty minutes later after we complained .  The manager was less than helpful or apologetic.  Our food was lukewarm at best.  My eggs were like eating leftovers and too boot there was no compensation or apologies on behalf of the restaurant.  Save your money and a headache and check our a classier better run establishment
#
#                  2  \
# 1  1.0 star rating
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       tokenized_text  \
# 1  [This, is, one, of, the, worst, restaurants, I, have, been, to, Myself, and, two, friends, had, a, reservation, for, 1145, as, we, had, theater, tickets, for, a, 200, show, When, I, entered, the, restaurant, I, was, greeted, by, a, woman, who, had, a, scowl, on, her, face, Once, my, friends, arrived, we, were, seated, in, a, booth, It, took, at, least, ten, to, fifteen, minutes, before, someone, came, to, take, our, drink, orders, our, drinks, were, delivered, with, minimal, taste, and, minimal, alcohol, I, ordered, a, seltzer, with, pomegranate, juice, and, I, got, seltzer, with, maybe, a, splash, of, cranberry, ...]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             parts_of_speech_reference  \
# 1  This is one of the worst restaurants I have been to Myself and two friends had a reservation for 1145 as we had theater tickets for a 200 show When I entered the restaurant I was greeted by a woman who had a scowl on her face Once my friends arrived we were seated in a booth It took at least ten to fifteen minutes before someone came to take our drink orders our drinks were delivered with minimal taste and minimal alcohol I ordered a seltzer with pomegranate juice and I got seltzer with maybe a splash of cranberry Our food arrived forty minutes later after we complained The manager was less than helpful or apologetic Our food was lukewarm at best My eggs were like eating leftovers and too boot there was no compensation or apologies on behalf of the restaurant Save your money and a headache and check our a classier better run establishment
#
#                                                                                                                                                                   nounchunk_list  \
# 1  [(the, worst, restaurants), (a, 200, show), (at, least, ten, to, fifteen, minutes), (our, drink, orders), (maybe, a, splash), (our, a, classier, better, run, establishment)]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      words_around_THE_A_AN  \
# 1  [[I, have, been, to, Myself, and, two, friends, had, a, reservation, for], [Myself, and, two, friends, had, a, reservation, for, 1145, as, we, had], [a, reservation, for, 1145, as, we, had, theater, tickets, for, a, 200], [we, had, theater, tickets, for, a, 200, show, When, I, entered, the], [a, 200, show, When, I, entered, the, restaurant, I, was, greeted, by], [I, entered, the, restaurant, I, was, greeted, by, a, woman, who, had], [the, restaurant, I, was, greeted, by, a, woman, who, had, a, scowl], [I, was, greeted, by, a, woman, who, had, a, scowl, on, her], [a, woman, who, had, a, scowl, on, her, face, Once, my, friends], [who, had, a, scowl, on, her, face, Once, my, friends, arrived, we], [a, scowl, on, her, face, Once, my, friends, arrived, we, were, seated], [we, were, seated, in, a, booth, It, took, at, least, ten, to], [a, booth, It, took, at, least, ten, to, fifteen, minutes, before, someone], [It, took, at, least, ten, to, fifteen, minutes, before, someone, came, to], [...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        AdjNouns_NounNouns_Service_Food_For  \
# 1  [[the, worst, restaurants, I, have], [reservation, for, 1145, as, we], [tickets, for, a, 200, show], [friends, arrived, we, were, seated], [drink, orders,  , our, drinks], [with, minimal, taste, and, minimal], [and, minimal, alcohol, .,  ], [I, ordered, a, seltzer, with], [with, pomegranate, juice, and, I], [I, got, seltzer, with, maybe], [food, arrived, forty, minutes, later], [like, eating, leftovers, and, too], [classier, better, run, establishment], [better, run, establishment]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              word_segments  \
# 1  [[worst, restaurants, I, have, been, to], [arrived, we, were, seated, in, a], [orders,  , our, drinks, were, delivered], [minimal, taste, and, minimal, alcohol, .], [minimal, alcohol, .,  , I, ordered], [ordered, a, seltzer, with, pomegranate, juice], [pomegranate, juice, and, I, got, seltzer], [got, seltzer, with, maybe, a, splash], [food, arrived, forty, minutes, later, after], [arrived, forty, minutes, later, after, we], [food, was, lukewarm, at, best, .], [eating, leftovers, and, too, boot, there], [I, have, been, to, .,  ], [Myself, and, two, friends, had, a], [a, reservation, for, 1145, as, we], [we, had, theater, tickets, for, a], [a, 200, show, .,  , When], [I, entered, the, restaurant, I, was], [the, restaurant, I, was, greeted, by], [I, was, greeted, by, a, woman], [a, woman, who, had, a, scowl], [who, had, a, scowl, on, her], [a, scowl, on, her, face, .], [we, were, seated, in, a, booth], [a, booth, .,  , It, took], [It, took, at, least, ten, to], [someone, came, to, tak...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     word_segments_unpacked
# 1  [worst, restaurants, I, have, been, to, arrived, we, were, seated, in, a, orders,  , our, drinks, were, delivered, minimal, taste, and, minimal, alcohol, ., minimal, alcohol, .,  , I, ordered, ordered, a, seltzer, with, pomegranate, juice, pomegranate, juice, and, I, got, seltzer, got, seltzer, with, maybe, a, splash, food, arrived, forty, minutes, later, after, arrived, forty, minutes, later, after, we, food, was, lukewarm, at, best, ., eating, leftovers, and, too, boot, there, I, have, been, to, .,  , Myself, and, two, friends, had, a, a, reservation, for, 1145, as, we, we, had, theater, tickets, for, a, a, 200, show, .,  , When, I, entered, the, restaurant, I, was, the, restaurant, I, was, greeted, by, I, was, greeted, by, a, woman, a, woman, who, had, a, scowl, who, had, a, scowl, on, her, a, scowl, on, her, face, ., we, were, seated, in, a, booth, a, booth, .,  , It, took, It, took, at, least, ten, to, someone, came, to, take, our, drink, I, ordered, a, seltzer, with, pomegran...

# %%
word_list_top_bottom = ''
for i in worst_term['word_segments_unpacked'][0]:
  i = i.replace(',','')
  word_list_top_bottom += i
print(word_list_top_bottom[:90])
# Out:
# [service was horrible . We had wait 25 minutes before someone served came in after and we

# %%
for i in list(str(worst_term['word_segments_unpacked'])):
  print(i)
# Out:
# 1
#
#
#
#
#
# [
# w
# o
# r
# s
# t
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# s
# ,
#
# I
# ,
#
# h
# a
# v
# e
# ,
#
# b
# e
# e
# n
# ,
#
# t
# o
# ,
#
# a
# r
# r
# i
# v
# e
# d
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# e
# a
# t
# e
# d
# ,
#
# i
# n
# ,
#
# a
# ,
#
# o
# r
# d
# e
# r
# s
# ,
#
#
# ,
#
# o
# u
# r
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# w
# e
# r
# e
# ,
#
# d
# e
# l
# i
# v
# e
# r
# e
# d
# ,
#
# m
# i
# n
# i
# m
# a
# l
# ,
#
# t
# a
# s
# t
# e
# ,
#
# a
# n
# d
# ,
#
# m
# i
# n
# i
# m
# a
# l
# ,
#
# a
# l
# c
# o
# h
# o
# l
# ,
#
# .
# ,
#
# m
# i
# n
# i
# m
# a
# l
# ,
#
# a
# l
# c
# o
# h
# o
# l
# ,
#
# .
# ,
#
#
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# s
# e
# l
# t
# z
# e
# r
# ,
#
# w
# i
# t
# h
# ,
#
# p
# o
# m
# e
# g
# r
# a
# n
# a
# t
# e
# ,
#
# j
# u
# i
# c
# e
# ,
#
# p
# o
# m
# e
# g
# r
# a
# n
# a
# t
# e
# ,
#
# j
# u
# i
# c
# e
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# g
# o
# t
# ,
#
# s
# e
# l
# t
# z
# e
# r
# ,
#
# g
# o
# t
# ,
#
# s
# e
# l
# t
# z
# e
# r
# ,
#
# w
# i
# t
# h
# ,
#
# m
# a
# y
# b
# e
# ,
#
# a
# ,
#
# s
# p
# l
# a
# s
# h
# ,
#
# f
# o
# o
# d
# ,
#
# a
# r
# r
# i
# v
# e
# d
# ,
#
# f
# o
# r
# t
# y
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# l
# a
# t
# e
# r
# ,
#
# a
# f
# t
# e
# r
# ,
#
# a
# r
# r
# i
# v
# e
# d
# ,
#
# f
# o
# r
# t
# y
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# l
# a
# t
# e
# r
# ,
#
# a
# f
# t
# e
# r
# ,
#
# w
# e
# ,
#
# f
# o
# o
# d
# ,
#
# w
# a
# s
# ,
#
# l
# u
# k
# e
# w
# a
# r
# m
# ,
#
# a
# t
# ,
#
# b
# e
# s
# t
# ,
#
# .
# ,
#
# e
# a
# t
# i
# n
# g
# ,
#
# l
# e
# f
# t
# o
# v
# e
# r
# s
# ,
#
# a
# n
# d
# ,
#
# t
# o
# o
# ,
#
# b
# o
# o
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# I
# ,
#
# h
# a
# v
# e
# ,
#
# b
# e
# e
# n
# ,
#
# t
# o
# ,
#
# .
# ,
#
#
# ,
#
# M
# y
# s
# e
# l
# f
# ,
#
# a
# n
# d
# ,
#
# t
# w
# o
# ,
#
# f
# r
# i
# e
# n
# d
# s
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# f
# o
# r
# ,
#
# 1
# 1
# 4
# 5
# ,
#
# a
# s
# ,
#
# w
# e
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# t
# h
# e
# a
# t
# e
# r
# ,
#
# t
# i
# c
# k
# e
# t
# s
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# a
# ,
#
# 2
# 0
# 0
# ,
#
# s
# h
# o
# w
# ,
#
# .
# ,
#
#
# ,
#
# W
# h
# e
# n
# ,
#
# I
# ,
#
# e
# n
# t
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# ,
#
# I
# ,
#
# w
# a
# s
# ,
#
# t
# h
# e
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# ,
#
# I
# ,
#
# w
# a
# s
# ,
#
# g
# r
# e
# e
# t
# e
# d
# ,
#
# b
# y
# ,
#
# I
# ,
#
# w
# a
# s
# ,
#
# g
# r
# e
# e
# t
# e
# d
# ,
#
# b
# y
# ,
#
# a
# ,
#
# w
# o
# m
# a
# n
# ,
#
# a
# ,
#
# w
# o
# m
# a
# n
# ,
#
# w
# h
# o
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# s
# c
# o
# w
# l
# ,
#
# w
# h
# o
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# s
# c
# o
# w
# l
# ,
#
# o
# n
# ,
#
# h
# e
# r
# ,
#
# a
# ,
#
# s
# c
# o
# w
# l
# ,
#
# o
# n
# ,
#
# h
# e
# r
# ,
#
# f
# a
# c
# e
# ,
#
# .
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# e
# a
# t
# e
# d
# ,
#
# i
# n
# ,
#
# a
# ,
#
# b
# o
# o
# t
# h
# ,
#
# a
# ,
#
# b
# o
# o
# t
# h
# ,
#
# .
# ,
#
#
# ,
#
# I
# t
# ,
#
# t
# o
# o
# k
# ,
#
# I
# t
# ,
#
# t
# o
# o
# k
# ,
#
# a
# t
# ,
#
# l
# e
# a
# s
# t
# ,
#
# t
# e
# n
# ,
#
# t
# o
# ,
#
# s
# o
# m
# e
# o
# n
# e
# ,
#
# c
# a
# m
# e
# ,
#
# t
# o
# ,
#
# t
# a
# k
# e
# ,
#
# o
# u
# r
# ,
#
# d
# r
# i
# n
# k
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# s
# e
# l
# t
# z
# e
# r
# ,
#
# w
# i
# t
# h
# ,
#
# p
# o
# m
# e
# g
# r
# a
# n
# .
# .
# .
#
#
# 7
#
#
#
#
#
# [
# f
# a
# v
# o
# r
# i
# t
# e
# ,
#
# l
# o
# c
# a
# l
# ,
#
# s
# p
# o
# t
# s
# ,
#
# .
# ,
#
# I
# ,
#
# m
# a
# d
# e
# ,
#
# l
# o
# c
# a
# l
# ,
#
# s
# p
# o
# t
# s
# ,
#
# .
# ,
#
# I
# ,
#
# m
# a
# d
# e
# ,
#
# a
# ,
#
# n
# o
# t
# ,
#
# t
# a
# k
# e
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# r
# e
# q
# u
# e
# s
# t
# s
# ,
#
# i
# n
# ,
#
# a
# d
# v
# a
# n
# c
# e
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# r
# e
# q
# u
# e
# s
# t
# s
# ,
#
# i
# n
# ,
#
# a
# d
# v
# a
# n
# c
# e
# ,
#
# .
# ,
#
# O
# k
# ,
#
# o
# r
# d
# e
# r
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# f
# o
# r
# ,
#
# d
# e
# s
# s
# e
# r
# t
# ,
#
# .
# ,
#
# t
# a
# k
# e
# ,
#
# c
# a
# r
# e
# ,
#
# o
# f
# ,
#
# i
# t
# ,
#
# .
# ,
#
# N
# e
# x
# t
# ,
#
# N
# e
# x
# t
# ,
#
# t
# h
# i
# n
# g
# ,
#
# I
# ,
#
# k
# n
# o
# w
# ,
#
# t
# h
# e
# ,
#
# c
# h
# e
# c
# k
# ,
#
# c
# o
# m
# e
# s
# ,
#
# a
# n
# d
# ,
#
# n
# o
# ,
#
# d
# e
# s
# s
# e
# r
# t
# ,
#
# .
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# ,
#
# i
# t
# ,
#
# !
# ,
#
# I
# ,
#
# s
# a
# i
# d
# ,
#
# e
# x
# c
# u
# s
# e
# ,
#
# o
# r
# d
# e
# r
# ,
#
# i
# t
# ,
#
# i
# n
# ,
#
# f
# r
# o
# n
# t
# ,
#
# o
# f
# ,
#
# m
# y
# ,
#
# n
# o
# t
# ,
#
# p
# o
# s
# s
# i
# b
# l
# e
# ,
#
# b
# e
# c
# a
# u
# s
# e
# ,
#
# h
# e
# ,
#
# a
# l
# r
# e
# a
# d
# y
# ,
#
# g
# a
# v
# e
# ,
#
# b
# a
# d
# ,
#
# t
# a
# s
# t
# e
# ,
#
# i
# n
# ,
#
# m
# y
# ,
#
# m
# o
# u
# t
# h
# ,
#
# f
# r
# o
# m
# ,
#
# I
# ,
#
# '
# m
# ,
#
# s
# o
# ,
#
# s
# a
# d
# ,
#
# t
# o
# ,
#
# w
# r
# i
# t
# e
# ,
#
# I
# ,
#
# m
# a
# d
# e
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# f
# o
# r
# ,
#
# d
# i
# n
# n
# e
# r
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# f
# o
# r
# ,
#
# d
# i
# n
# n
# e
# r
# ,
#
# f
# o
# r
# ,
#
# m
# y
# ,
#
# I
# ,
#
# c
# a
# l
# l
# e
# d
# ,
#
# t
# h
# e
# ,
#
# d
# a
# y
# ,
#
# b
# e
# f
# o
# r
# e
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# d
# a
# y
# ,
#
# b
# e
# f
# o
# r
# e
# ,
#
# a
# n
# d
# ,
#
# a
# s
# k
# e
# d
# ,
#
# t
# h
# e
# m
# ,
#
# t
# h
# e
# m
# ,
#
# t
# o
# ,
#
# m
# a
# k
# e
# ,
#
# a
# ,
#
# n
# o
# t
# e
# ,
#
# t
# h
# a
# t
# ,
#
# a
# ,
#
# n
# o
# t
# e
# ,
#
# t
# h
# a
# t
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# h
# i
# s
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# h
# i
# s
# ,
#
# b
# i
# r
# t
# h
# d
# a
# y
# ,
#
# a
# n
# d
# ,
#
# a
# s
# k
# e
# d
# ,
#
# i
# t
# ,
#
# w
# o
# u
# l
# d
# ,
#
# b
# e
# ,
#
# p
# o
# s
# s
# i
# b
# l
# e
# ,
#
# t
# o
# ,
#
# b
# r
# i
# n
# g
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# o
# u
# t
# ,
#
# f
# o
# r
# ,
#
# d
# e
# s
# s
# e
# r
# t
# ,
#
# .
# ,
#
# T
# h
# e
# y
# ,
#
# t
# o
# l
# d
# ,
#
# m
# e
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# m
# e
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# s
# p
# e
# a
# k
# ,
#
# t
# o
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# s
# p
# e
# a
# k
# ,
#
# t
# o
# ,
#
# t
# h
# e
# ,
#
# t
# h
# e
# y
# ,
#
# d
# o
# ,
#
# n
# o
# t
# ,
#
# t
# a
# k
# e
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# r
# e
# q
# u
# e
# s
# t
# s
# ,
#
# w
# e
# ,
#
# a
# r
# r
# i
# v
# e
# d
# ,
#
# I
# ,
#
# t
# o
# o
# k
# ,
#
# t
# h
# e
# ,
#
# w
# a
# i
# t
# e
# r
# ,
#
# I
# ,
#
# t
# o
# o
# k
# ,
#
# t
# h
# e
# ,
#
# w
# a
# i
# t
# e
# r
# ,
#
# a
# s
# i
# d
# e
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# w
# a
# i
# t
# e
# r
# ,
#
# a
# s
# i
# d
# e
# ,
#
# a
# n
# d
# ,
#
# t
# o
# l
# d
# ,
#
# h
# i
# m
# .
# .
# .
#
#
# 0
#
#
#
#
#
# [
# s
# e
# r
# v
# i
# c
# e
# ,
#
# w
# a
# s
# ,
#
# h
# o
# r
# r
# i
# b
# l
# e
# ,
#
# .
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# w
# a
# i
# t
# ,
#
# 2
# 5
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# b
# e
# f
# o
# r
# e
# ,
#
# s
# o
# m
# e
# o
# n
# e
# ,
#
# s
# e
# r
# v
# e
# d
# ,
#
# c
# a
# m
# e
# ,
#
# i
# n
# ,
#
# a
# f
# t
# e
# r
# ,
#
# a
# n
# d
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# o
# r
# d
# e
# r
# ,
#
# g
# a
# v
# e
# ,
#
# u
# s
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# g
# a
# v
# e
# ,
#
# u
# s
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# A
# n
# d
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# f
# o
# o
# d
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# f
# o
# o
# d
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# f
# o
# o
# d
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# w
# a
# i
# t
# ,
#
# a
# n
# d
# ,
#
# w
# a
# s
# ,
#
# w
# a
# i
# t
# ,
#
# a
# n
# d
# ,
#
# w
# a
# s
# ,
#
# n
# '
# t
# ,
#
# w
# o
# r
# t
# h
# ,
#
# i
# t
# ,
#
# n
# o
# t
# ,
#
# r
# e
# c
# o
# m
# m
# e
# n
# d
# ,
#
# a
# t
# ,
#
# a
# l
# l
# ,
#
# f
# o
# r
# ,
#
# t
# h
# e
# ,
#
# e
# x
# p
# e
# c
# t
# ,
#
# w
# a
# y
# ,
#
# b
# e
# t
# t
# e
# r
# ,
#
# s
# t
# a
# n
# d
# a
# r
# d
# s
# ,
#
# .
# ,
#
# H
# o
# p
# i
# n
# g
# ,
#
# b
# e
# t
# t
# e
# r
# ,
#
# s
# t
# a
# n
# d
# a
# r
# d
# s
# ,
#
# .
# ,
#
# H
# o
# p
# i
# n
# g
# ,
#
# t
# h
# a
# t
# ,
#
# m
# a
# n
# a
# g
# e
# m
# e
# n
# t
# ,
#
# s
# e
# e
# s
# ,
#
# t
# h
# i
# s
# ,
#
# s
# o
# ,
#
# I
# ,
#
# c
# a
# n
# ,
#
# r
# e
# t
# u
# r
# n
# ,
#
# T
# h
# e
# ,
#
# a
# m
# b
# i
# a
# n
# c
# e
# ,
#
# i
# s
# ,
#
# g
# r
# e
# a
# t
# ,
#
# .
# ,
#
# B
# u
# t
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# w
# a
# i
# t
# ,
#
# 2
# 5
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# s
# o
# m
# e
# o
# n
# e
# ,
#
# s
# e
# r
# v
# e
# d
# ,
#
# u
# s
# ,
#
# .
# ,
#
# P
# e
# o
# p
# l
# e
# ,
#
# c
# a
# m
# e
# ,
#
# u
# s
# ,
#
# .
# ,
#
# P
# e
# o
# p
# l
# e
# ,
#
# c
# a
# m
# e
# ,
#
# i
# n
# ,
#
# a
# f
# t
# e
# r
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# t
# i
# l
# l
# ,
#
# s
# e
# r
# v
# e
# d
# ,
#
# a
# f
# t
# e
# r
# ,
#
# t
# h
# e
# y
# ,
#
# t
# h
# e
# y
# ,
#
# w
# e
# r
# e
# ,
#
# .
# ,
#
# T
# h
# e
# n
# ,
#
# t
# h
# e
# r
# e
# ,
#
# w
# a
# s
# ,
#
# t
# h
# e
# r
# e
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# h
# a
# i
# r
# ,
#
# o
# n
# ,
#
# m
# y
# ,
#
# a
# ,
#
# h
# a
# i
# r
# ,
#
# o
# n
# ,
#
# m
# y
# ,
#
# o
# l
# i
# v
# e
# s
# ,
#
# t
# h
# a
# t
# ,
#
# t
# h
# e
# y
# ,
#
# m
# e
# s
# s
# e
# d
# ,
#
# u
# p
# ,
#
# o
# u
# r
# ,
#
# o
# r
# d
# e
# r
# ,
#
# g
# a
# v
# e
# ,
#
# u
# s
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# A
# n
# d
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# a
# s
# k
# ,
#
# f
# o
# r
# ,
#
# t
# h
# e
# ,
#
# t
# h
# e
# r
# e
# ,
#
# c
# o
# u
# l
# d
# ,
#
# b
# e
# ,
#
# r
# o
# o
# m
# ,
#
# f
# o
# r
# ,
#
# o
# u
# r
# ,
#
# T
# h
# e
# ,
#
# f
# o
# o
# d
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# w
# a
# i
# t
# ,
#
# a
# n
# d
# ,
#
# a
# ,
#
# w
# a
# i
# t
# ,
#
# a
# n
# d
# ,
#
# w
# a
# s
# ,
#
# n
# '
# t
# ,
#
# w
# o
# r
# t
# h
# ,
#
# i
# t
# ,
#
# t
# h
# e
# ,
#
# .
# .
# .
#
#
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# h
# a
# r
# d
# ,
#
# t
# i
# m
# e
# ,
#
# h
# e
# a
# r
# i
# n
# g
# ,
#
# t
# h
# e
# ,
#
# o
# r
# d
# e
# r
# s
# ,
#
# .
# ]
#
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# b
# u
# t
# ,
#
# v
# e
# r
# y
# ,
#
# b
# l
# a
# n
# d
# ,
#
# .
# ,
#
#
# ,
#
# W
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# a
# n
# d
# ,
#
# p
# o
# r
# k
# ,
#
# n
# o
# t
# ,
#
# w
# o
# r
# t
# h
# ,
#
# t
# h
# e
# ,
#
# c
# a
# l
# o
# r
# i
# e
# s
# ,
#
# .
# ,
#
#
# ,
#
# C
# h
# e
# a
# p
# ,
#
# w
# i
# n
# e
# ,
#
# g
# l
# a
# s
# s
# e
# s
# ,
#
# b
# u
# t
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# b
# u
# t
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# n
# i
# c
# e
# ,
#
# s
# m
# o
# o
# t
# h
# ,
#
# I
# t
# a
# l
# i
# a
# n
# ,
#
# I
# t
# a
# l
# i
# a
# n
# ,
#
# r
# e
# d
# ,
#
# w
# i
# n
# e
# ,
#
# .
# ,
#
#
# ,
#
# T
# h
# e
# ,
#
# r
# e
# d
# ,
#
# w
# i
# n
# e
# ,
#
# .
# ,
#
#
# ,
#
# T
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# G
# r
# e
# a
# t
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# t
# h
# o
# u
# g
# h
# ,
#
# a
# n
# d
# ,
#
# d
# e
# c
# e
# n
# t
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# t
# h
# o
# u
# g
# h
# ,
#
# a
# n
# d
# ,
#
# d
# e
# c
# e
# n
# t
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# .
# ,
#
# W
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# a
# n
# d
# ,
#
# p
# o
# r
# k
# ,
#
# d
# u
# m
# p
# l
# i
# n
# g
# s
# ,
#
# a
# ,
#
# n
# i
# c
# e
# ,
#
# s
# m
# o
# o
# t
# h
# ,
#
# I
# t
# a
# l
# i
# a
# n
# ,
#
# r
# e
# d
# ,
#
# w
# i
# n
# e
# ,
#
# T
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# w
# e
# r
# e
# ,
#
# s
# w
# i
# m
# m
# i
# n
# g
# ,
#
# i
# n
# ]
#
#
# 5
#
#
#
#
#
# [
# n
# o
# t
# ,
#
# g
# r
# e
# a
# t
# ,
#
# .
# ,
#
# F
# o
# r
# ,
#
# s
# t
# a
# r
# t
# e
# r
# s
# ,
#
# t
# h
# e
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# p
# o
# l
# i
# c
# y
# ,
#
# i
# s
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# c
# o
# n
# f
# u
# s
# i
# n
# g
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# o
# ,
#
# d
# o
# ,
#
# t
# h
# e
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# (
# ,
#
# $
# ,
#
# 2
# 8
# ,
#
# )
# ,
#
# -
# ,
#
# f
# i
# x
# ,
#
# m
# e
# n
# u
# ,
#
# .
# .
# .
# ,
#
# s
# o
# ,
#
# a
# l
# l
# ,
#
# f
# i
# x
# ,
#
# m
# e
# n
# u
# ,
#
# .
# .
# .
# ,
#
# s
# o
# ,
#
# a
# l
# l
# ,
#
# i
# n
# ,
#
# b
# u
# t
# ,
#
# w
# h
# a
# t
# e
# v
# s
# ,
#
# .
# ,
#
# W
# e
# ,
#
# o
# p
# t
# e
# d
# ,
#
# a
# g
# a
# i
# n
# s
# t
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# a
# n
# d
# ,
#
# e
# n
# t
# r
# e
# e
# s
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# b
# u
# t
# ,
#
# i
# n
# a
# t
# t
# e
# n
# t
# i
# v
# e
# ,
#
# .
# ,
#
# W
# h
# e
# n
# ,
#
# o
# u
# r
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# c
# a
# m
# e
# ,
#
# w
# e
# ,
#
# a
# s
# k
# e
# d
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# s
# t
# r
# a
# w
# ,
#
# w
# a
# i
# t
# ,
#
# f
# o
# r
# ,
#
# o
# u
# r
# ,
#
# e
# n
# t
# r
# e
# e
# s
# ,
#
# f
# o
# r
# ,
#
# q
# u
# i
# t
# e
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# b
# a
# r
# t
# e
# n
# d
# e
# r
# ,
#
# w
# a
# s
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# i
# n
# v
# o
# l
# v
# e
# d
# ,
#
# o
# t
# h
# e
# r
# ,
#
# b
# a
# r
# t
# e
# n
# d
# e
# r
# ,
#
# t
# o
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# I
# t
# s
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# I
# t
# s
# ,
#
# a
# ,
#
# t
# i
# n
# y
# ,
#
# b
# a
# r
# ,
#
# t
# i
# n
# y
# ,
#
# b
# a
# r
# ,
#
# t
# o
# o
# ,
#
# s
# o
# ,
#
# h
# o
# w
# ,
#
# w
# e
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# c
# o
# n
# f
# u
# s
# i
# n
# g
# ,
#
# .
# ,
#
# I
# n
# ,
#
# o
# r
# d
# e
# r
# ,
#
# y
# o
# u
# ,
#
# h
# a
# v
# e
# ,
#
# t
# o
# ,
#
# d
# o
# ,
#
# t
# h
# e
# ,
#
# p
# r
# e
# ,
#
# a
# ,
#
# l
# i
# t
# h
# l
# e
# ,
#
# s
# t
# e
# e
# p
# ,
#
# e
# v
# e
# n
# ,
#
# f
# o
# r
# ,
#
# M
# a
# n
# h
# a
# t
# t
# a
# n
# ,
#
# W
# e
# ,
#
# o
# p
# t
# e
# d
# ,
#
# a
# g
# a
# i
# n
# s
# t
# ,
#
# t
# h
# a
# t
# ,
#
# a
# n
# d
# ,
#
# j
# u
# s
# t
# ,
#
# T
# h
# e
# ,
#
# b
# a
# r
# t
# e
# n
# d
# e
# r
# ,
#
# w
# a
# s
# ,
#
# s
# w
# e
# e
# t
# ,
#
# b
# u
# t
# ,
#
# i
# n
# a
# t
# t
# e
# n
# t
# i
# v
# e
# ,
#
# w
# e
# ,
#
# a
# s
# k
# e
# d
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# s
# t
# r
# a
# w
# ,
#
# t
# h
# a
# t
# ,
#
# a
# ,
#
# s
# t
# r
# a
# w
# ,
#
# t
# h
# a
# t
# ,
#
# n
# e
# v
# e
# r
# ,
#
# c
# a
# m
# e
# ,
#
# .
# ,
#
# W
# e
# ,
#
# t
# h
# e
# n
# ,
#
# p
# r
# o
# c
# e
# e
# d
# e
# d
# ,
#
# t
# o
# ,
#
# w
# a
# i
# t
# ,
#
# f
# o
# r
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# f
# i
# n
# i
# s
# h
# e
# d
# ,
#
# o
# u
# r
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# a
# w
# h
# i
# l
# e
# ,
#
# u
# s
# ,
#
# o
# r
# ,
#
# a
# s
# k
# ,
#
# i
# f
# ,
#
# w
# e
# ,
#
# w
# a
# n
# t
# e
# d
# ,
#
# w
# e
# ,
#
# w
# a
# n
# t
# e
# d
# ,
#
# a
# n
# o
# t
# h
# e
# r
# ,
#
# r
# o
# u
# n
# d
# ,
#
# .
# ,
#
# W
# e
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# f
# l
# a
# g
# ,
#
# d
# o
# w
# n
# ,
#
# t
# h
# e
# ,
#
# a
# ,
#
# t
# i
# n
# y
# ,
#
# b
# a
# r
# ,
#
# t
# o
# o
# ,
#
# s
# o
# ,
#
# h
# o
# w
# ,
#
# w
# e
# ,
#
# c
# o
# u
# l
# d
# ,
#
# b
# e
# ,
# .
# .
# .
#
#
# 1
# 2
#
#
#
#
# [
# n
# e
# w
# ,
#
# r
# e
# v
# i
# e
# w
# ,
#
# i
# n
# ,
#
# O
# c
# t
# o
# b
# e
# r
# ,
#
# o
# f
# ,
#
# 2
# 0
# 1
# 9
# ,
#
# s
# m
# a
# l
# l
# ,
#
# p
# l
# a
# t
# e
# s
# ,
#
# ,
# ,
#
# I
# ,
#
# g
# e
# t
# ,
#
# i
# t
# ,
#
# n
# e
# w
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# i
# s
# ,
#
# a
# ,
#
# $
# ,
#
# 2
# 3
# ,
#
# n
# o
# t
# ,
#
# m
# u
# c
# h
# ,
#
# i
# n
# ,
#
# N
# Y
# C
# ,
#
# ,
# ,
#
# b
# u
# t
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# q
# u
# a
# l
# i
# t
# y
# ,
#
# w
# a
# s
# ,
#
# n
# o
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# n
# o
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# a
# n
# y
# m
# o
# r
# e
# ,
#
# a
# n
# d
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# e
# v
# e
# r
# a
# l
# ,
#
# p
# l
# a
# t
# e
# s
# ,
#
# a
# r
# r
# i
# v
# i
# n
# g
# ,
#
# a
# t
# ,
#
# o
# n
# c
# e
# ,
#
# a
# n
# d
# ,
#
# a
# r
# r
# i
# v
# i
# n
# g
# ,
#
# a
# t
# ,
#
# o
# n
# c
# e
# ,
#
# a
# n
# d
# ,
#
# n
# o
# t
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# n
# o
# t
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# h
# o
# t
# ,
#
# .
# ,
#
#
# ,
#
# S
# i
# n
# c
# e
# ,
#
# n
# o
# t
# ,
#
# y
# e
# t
# ,
#
# c
# r
# o
# w
# d
# e
# d
# ,
#
# s
# o
# ,
#
# I
# ,
#
# d
# o
# ,
#
# w
# a
# i
# t
# ,
#
# s
# t
# a
# f
# f
# ,
#
# w
# a
# s
# ,
#
# p
# r
# o
# f
# e
# s
# s
# i
# o
# n
# a
# l
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# p
# l
# a
# t
# e
# s
# ,
#
# w
# e
# r
# e
# ,
#
# p
# r
# e
# s
# e
# n
# t
# e
# d
# ,
#
# s
# l
# o
# p
# p
# i
# l
# y
# ,
#
# n
# o
# t
# ,
#
# a
# ,
#
# p
# l
# e
# a
# s
# a
# n
# t
# ,
#
# e
# x
# p
# e
# r
# i
# e
# n
# c
# e
# ,
#
# .
# ,
#
#
# ,
#
# p
# l
# e
# a
# s
# a
# n
# t
# ,
#
# e
# x
# p
# e
# r
# i
# e
# n
# c
# e
# ,
#
# .
# ,
#
#
# ,
#
# W
# h
# a
# t
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# o
# r
# d
# e
# r
# ,
#
# ,
# ,
#
# y
# o
# u
# ,
#
# p
# a
# y
# ,
#
# f
# o
# r
# ,
#
# e
# v
# e
# r
# y
# ,
#
# e
# n
# j
# o
# y
# e
# d
# ,
#
# 3
# ,
#
# r
# e
# f
# i
# l
# l
# s
# ,
#
# o
# f
# ,
#
# c
# o
# f
# f
# e
# e
# ,
#
# ,
# ,
#
# w
# e
# a
# k
# ,
#
# t
# e
# a
# ,
#
# b
# a
# g
# ,
#
# a
# n
# d
# ,
#
# h
# a
# d
# ,
#
# n
# o
# ,
#
# s
# e
# c
# o
# n
# d
# ,
#
# r
# e
# q
# u
# e
# s
# t
# ,
#
# .
# ,
#
#
# ,
#
# I
# ,
#
# s
# u
# p
# p
# o
# s
# e
# ,
#
# b
# u
# t
# ,
#
# m
# y
# ,
#
# h
# u
# s
# b
# a
# n
# d
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# a
# r
# e
# ,
#
# I
# ,
#
# a
# m
# ,
#
# w
# r
# i
# t
# i
# n
# g
# ,
#
# t
# h
# i
# s
# ,
#
# n
# e
# w
# ,
#
# r
# e
# v
# i
# e
# w
# ,
#
# I
# ,
#
# w
# e
# r
# e
# ,
#
# v
# e
# r
# y
# ,
#
# d
# i
# s
# a
# p
# p
# o
# i
# n
# t
# e
# d
# ,
#
# i
# n
# ,
#
# o
# u
# r
# ,
#
# T
# h
# e
# ,
#
# m
# e
# a
# l
# ,
#
# i
# n
# ,
#
# n
# o
# ,
#
# l
# o
# n
# g
# e
# r
# ,
#
# a
# l
# l
# ,
#
# y
# o
# u
# ,
#
# c
# a
# n
# ,
#
# e
# a
# t
# ,
#
# s
# m
# a
# l
# l
# ,
#
# p
# l
# a
# t
# e
# s
# ,
#
# ,
# ,
#
# I
# ,
#
# g
# e
# t
# ,
#
# i
# t
# ,
#
# ,
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# i
# t
# ,
#
# ,
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# e
# x
# p
# e
# n
# s
# i
# v
# e
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# e
# x
# p
# e
# n
# s
# i
# v
# e
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# r
# e
# ,
#
# '
# s
# ,
#
# t
# h
# e
# r
# e
# ,
#
# '
# s
# ,
#
# a
# ,
#
# l
# o
# t
# ,
#
# o
# f
# ,
#
# w
# a
# s
# t
# e
# ,
#
# a
# ,
#
# l
# o
# t
# ,
#
# o
# f
# ,
#
# w
# a
# s
# t
# e
# ,
#
# .
# ,
#
#
# ,
#
# T
# h
# e
# ,
#
# n
# e
# w
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# i
# s
# ,
#
# a
# ,
#
# $
# ,
#
# a
# ,
#
# $
# ,
#
# 2
# 3
# ,
#
# p
# r
# i
# c
# e
# ,
#
# f
# i
# x
# e
# ,
# .
# .
# .
#
#
# 1
# 7
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# b
# u
# t
# ,
#
# i
# t
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# .
# ,
#
# M
# y
# ,
#
# n
# o
# n
# G
# F
# ,
#
# f
# r
# i
# e
# n
# d
# s
# ,
#
# w
# e
# r
# e
# ,
#
# h
# a
# p
# p
# y
# ,
#
# w
# i
# t
# h
# ,
#
# t
# h
# e
# i
# r
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# i
# r
# ,
#
# m
# e
# a
# l
# s
# ,
#
# w
# e
# r
# e
# ,
#
# a
# v
# e
# r
# a
# g
# e
# ,
#
# -
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# a
# n
# d
# ,
#
# r
# e
# q
# u
# e
# s
# t
# e
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# v
# e
# g
# e
# t
# a
# b
# l
# e
# ,
#
# b
# u
# t
# ,
#
# t
# h
# a
# t
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# b
# u
# t
# ,
#
# t
# h
# a
# t
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# h
# a
# p
# p
# e
# n
# ,
#
# .
# ,
#
# S
# e
# r
# v
# i
# c
# e
# ,
#
# w
# a
# s
# ,
#
# a
# d
# e
# q
# u
# a
# t
# e
# ,
#
# a
# s
# ,
#
# w
# a
# s
# ,
#
# t
# h
# e
# ,
#
# i
# t
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# .
# ,
#
# M
# y
# ,
#
# n
# o
# n
# G
# F
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# a
# n
# d
# ,
#
# r
# e
# q
# u
# e
# s
# t
# e
# d
# ,
#
# t
# h
# e
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# a
# n
# d
# ,
#
# r
# e
# q
# u
# e
# s
# t
# e
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# v
# e
# g
# e
# t
# a
# b
# l
# e
# ,
#
# b
# u
# t
# ,
#
# t
# h
# a
# t
# ,
#
# d
# i
# d
# ]
#
#
# 1
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# b
# u
# t
# ,
#
# d
# i
# d
# ,
#
# n
# '
# t
# ,
#
# s
# t
# a
# n
# d
# ,
#
# o
# u
# t
# ,
#
# .
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# d
# u
# m
# p
# l
# i
# n
# g
# s
# ,
#
# ,
# ,
#
# t
# h
# e
# ,
#
# d
# u
# c
# k
# ,
#
# W
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# d
# u
# m
# p
# l
# i
# n
# g
# s
# ,
#
# ,
# ,
#
# t
# h
# e
# ,
#
# t
# h
# e
# ,
#
# d
# u
# m
# p
# l
# i
# n
# g
# s
# ,
#
# ,
# ,
#
# t
# h
# e
# ,
#
# d
# u
# c
# k
# ,
#
# t
# u
# r
# n
# o
# v
# e
# r
# ]
#
#
# 1
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# f
# i
# r
# s
# t
# ,
#
# t
# i
# m
# e
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# h
# e
# r
# e
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# h
# e
# r
# e
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# i
# t
# s
# e
# l
# f
# ,
#
# b
# u
# t
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# s
# u
# p
# e
# r
# ,
#
# c
# o
# z
# y
# ,
#
# a
# n
# d
# ,
#
# -
# ,
#
# f
# i
# x
# e
# d
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# s
# i
# n
# c
# e
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# f
# i
# x
# e
# d
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# s
# i
# n
# c
# e
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# 1
# 8
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# (
# ,
#
# w
# h
# i
# c
# h
# ,
#
# c
# a
# m
# e
# ,
#
# o
# u
# t
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# s
# h
# a
# r
# e
# s
# ,
#
# (
# ,
#
# a
# l
# s
# o
# ,
#
# c
# a
# m
# e
# ,
#
# o
# u
# t
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# e
# n
# t
# r
# e
# e
# s
# ,
#
# (
# ,
#
# w
# h
# i
# c
# h
# ,
#
# w
# e
# ,
#
# g
# o
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# w
# h
# i
# c
# h
# e
# v
# e
# r
# ,
#
# o
# n
# e
# ,
#
# w
# e
# ,
#
# w
# a
# n
# t
# e
# d
# ,
#
# )
# ,
#
# I
# ,
#
# c
# a
# m
# e
# ,
#
# h
# e
# r
# e
# ,
#
# f
# o
# r
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# f
# o
# r
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# m
# y
# ,
#
# f
# i
# r
# s
# t
# ,
#
# t
# i
# m
# e
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# T
# h
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# i
# t
# s
# e
# l
# f
# ,
#
# w
# a
# s
# ,
#
# s
# m
# a
# l
# l
# e
# r
# ,
#
# t
# h
# a
# n
# ,
#
# i
# t
# s
# e
# l
# f
# ,
#
# w
# a
# s
# ,
#
# s
# m
# a
# l
# l
# e
# r
# ,
#
# t
# h
# a
# n
# ,
#
# I
# ,
#
# e
# x
# p
# e
# c
# t
# e
# d
# ,
#
# I
# ,
#
# e
# x
# p
# e
# c
# t
# e
# d
# ,
#
# b
# u
# t
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# s
# u
# p
# e
# r
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# s
# u
# p
# e
# r
# ,
#
# c
# o
# z
# y
# ,
#
# a
# n
# d
# ,
#
# c
# u
# t
# e
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# d
# e
# f
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# d
# e
# f
# ,
#
# r
# e
# c
# o
# m
# m
# e
# n
# d
# ,
#
# o
# n
# e
# ,
#
# s
# i
# n
# c
# e
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# p
# r
# e
# t
# t
# y
# ,
#
# p
# a
# c
# k
# e
# d
# ,
#
# w
# h
# e
# n
# ,
#
# I
# ,
#
# I
# ,
#
# a
# r
# r
# i
# v
# e
# d
# ,
#
# a
# t
# ,
#
# 1
# ,
#
# p
# m
# ,
#
# o
# n
# ,
#
# a
# ,
#
# S
# a
# t
# u
# r
# d
# a
# y
# ,
#
# .
# ,
#
# W
# e
# ,
#
# w
# e
# n
# t
# ,
#
# w
# i
# t
# h
# ,
#
# W
# e
# ,
#
# w
# e
# n
# t
# ,
#
# w
# i
# t
# h
# ,
#
# t
# h
# e
# ,
#
# p
# r
# e
# ,
#
# -
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# 1
# 8
# ,
#
# p
# e
# o
# p
# l
# e
# ,
#
# .
# ,
#
# W
# e
# ,
#
# W
# e
# ,
#
# h
# a
# d
# ,
#
# t
# h
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# o
# f
# ,
#
# 4
# ,
#
# u
# s
# ,
#
# )
# ,
#
# ,
# ,
#
# 3
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# s
# h
# a
# r
# e
# s
# ,
#
# w
# e
# ,
#
# g
# o
# t
# ,
#
# t
# o
# ,
#
# o
# r
# d
# e
# r
# ,
#
# w
# h
# i
# c
# h
# e
# v
# e
# r
# ,
#
# o
# n
# e
# ]
#
#
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# s
# w
# a
# n
# k
# y
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# w
# i
# t
# h
# ,
#
# a
# n
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# w
# i
# t
# h
# ,
#
# a
# n
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# ,
# ,
#
# g
# i
# v
# e
# s
# ,
#
# w
# a
# y
# ,
#
# t
# o
# ,
#
# t
# h
# e
# ,
#
# N
# Y
# C
# ,
#
# v
# i
# b
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# F
# r
# i
# e
# s
# ,
#
# a
# n
# d
# ,
#
# d
# i
# p
# p
# i
# n
# g
# ,
#
# s
# a
# u
# c
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# g
# r
# e
# e
# n
# ,
#
# p
# a
# s
# t
# a
# ,
#
# ,
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# g
# r
# e
# e
# n
# ,
#
# p
# a
# s
# t
# a
# ,
#
# ,
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# A
# ,
#
# s
# w
# a
# n
# k
# y
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# w
# i
# t
# h
# ,
#
# a
# n
# ,
#
# a
# n
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# ,
# ,
#
# t
# h
# o
# u
# g
# h
# ,
#
# v
# e
# r
# y
# ,
#
# l
# o
# u
# d
# ,
#
# t
# h
# e
# ,
#
# b
# i
# l
# l
# ,
#
# t
# o
# ,
#
# o
# n
# l
# y
# ,
#
# p
# a
# y
# ,
#
# f
# o
# r
# ,
#
# w
# h
# a
# t
# ,
#
# w
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# F
# r
# i
# e
# s
# ,
#
# a
# n
# d
# ,
#
# w
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# F
# r
# i
# e
# s
# ,
#
# a
# n
# d
# ,
#
# d
# i
# p
# p
# i
# n
# g
# ,
#
# t
# h
# e
# ,
#
# g
# r
# e
# e
# n
# ,
#
# p
# a
# s
# t
# a
# ,
#
# ,
# ,
#
# s
# c
# a
# l
# l
# o
# p
# s
# ,
#
# ,
# ,
#
# E
# v
# e
# r
# y
# o
# n
# e
# ,
#
# w
# a
# s
# ,
#
# v
# e
# r
# y
# ,
#
# h
# a
# p
# p
# y
# ,
#
# w
# i
# t
# h
# ,
#
# t
# h
# e
# i
# r
# ,
#
# a
# n
# ,
#
# e
# l
# e
# m
# e
# n
# t
# ,
#
# o
# f
# ,
#
# e
# x
# p
# e
# r
# i
# m
# e
# n
# t
# a
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# s
# u
# r
# p
# r
# i
# s
# e
# ]
#
#
# 1
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# o
# t
# h
# e
# r
# ,
#
# n
# i
# g
# h
# t
# ,
#
# .
# ,
#
# W
# e
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# e
# n
# j
# o
# y
# e
# d
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# h
# e
# s
# e
# ,
#
# !
# ,
#
# R
# e
# a
# l
# l
# y
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# g
# o
# o
# d
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# o
# m
# e
# ,
#
# n
# i
# c
# e
# ,
#
# c
# h
# o
# i
# c
# e
# s
# ,
#
# u
# s
# ,
#
# e
# n
# d
# e
# d
# ,
#
# u
# p
# ,
#
# h
# e
# r
# e
# ,
#
# a
# f
# t
# e
# r
# ,
#
# a
# ,
#
# a
# ,
#
# s
# h
# o
# w
# ,
#
# t
# h
# e
# ,
#
# o
# t
# h
# e
# r
# ,
#
# n
# i
# g
# h
# t
# ,
#
# .
# ,
#
# W
# e
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# e
# n
# j
# o
# y
# e
# d
# ,
#
# i
# t
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# t
# h
# i
# n
# k
# ,
#
# y
# o
# u
# ,
#
# w
# o
# u
# l
# d
# ,
#
# y
# o
# u
# ,
#
# w
# o
# u
# l
# d
# ,
#
# a
# s
# ,
#
# w
# e
# l
# l
# ,
#
# .
# ,
#
# T
# h
# u
# m
# b
# s
# ,
#
# y
# o
# u
# ,
#
# l
# i
# k
# e
# ,
#
# b
# r
# u
# s
# s
# e
# l
# s
# ,
#
# s
# p
# r
# o
# u
# t
# s
# ,
#
# ,
# ,
#
# b
# e
# ,
#
# T
# h
# e
# ,
#
# w
# i
# n
# e
# ,
#
# l
# i
# s
# t
# ,
#
# w
# a
# s
# ,
#
# n
# '
# t
# ,
#
# s
# u
# p
# e
# r
# ,
#
# t
# h
# e
# r
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# o
# m
# e
# ,
#
# n
# i
# c
# e
# ,
#
# c
# h
# o
# i
# c
# e
# s
# ,
#
# a
# v
# a
# i
# l
# a
# b
# l
# e
# ]
#
#
# 1
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# f
# o
# o
# d
# ,
#
# a
# n
# d
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# h
# e
# r
# e
# ,
#
# a
# r
# e
# ,
#
# g
# r
# e
# a
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# h
# e
# ,
#
# b
# r
# o
# c
# c
# o
# l
# i
# ,
#
# ,
# ,
#
# m
# u
# s
# h
# r
# o
# o
# m
# ,
#
# p
# i
# z
# z
# a
# ,
#
# G
# r
# e
# a
# t
# ,
#
# a
# m
# b
# i
# a
# n
# c
# e
# ,
#
# t
# o
# ,
#
# h
# a
# n
# g
# ,
#
# o
# u
# t
# ,
#
# w
# i
# t
# h
# ,
#
# T
# h
# e
# ,
#
# f
# o
# o
# d
# ,
#
# a
# n
# d
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# h
# e
# r
# e
# ,
#
# a
# r
# e
# ,
#
# w
# e
# ,
#
# a
# l
# w
# a
# y
# s
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# h
# e
# ,
#
# b
# r
# o
# c
# c
# o
# l
# i
# ,
#
# ,
# ,
#
# t
# h
# e
# ,
#
# b
# r
# o
# c
# c
# o
# l
# i
# ,
#
# ,
# ,
#
# m
# u
# s
# h
# r
# o
# o
# m
# ,
#
# p
# i
# z
# z
# a
# ,
#
# ,
# ]
#
#
# 1
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# I
# t
# a
# l
# i
# a
# n
# ,
#
# f
# o
# o
# d
# ,
#
# f
# a
# n
# a
# t
# i
# c
# ,
#
# ,
# ,
#
# s
# o
# ,
#
# o
# n
# c
# e
# ,
#
# f
# o
# o
# d
# ,
#
# f
# a
# n
# a
# t
# i
# c
# ,
#
# ,
# ,
#
# s
# o
# ,
#
# o
# n
# c
# e
# ,
#
# I
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# m
# e
# n
# u
# ,
#
# ,
# ,
#
# I
# ,
#
# f
# i
# g
# u
# r
# e
# d
# ,
#
# I
# ,
#
# m
# a
# i
# n
# ,
#
# c
# o
# u
# r
# s
# e
# ,
#
# ,
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# S
# a
# l
# m
# o
# n
# ,
#
# .
# ,
#
# B
# E
# S
# T
# ,
#
# D
# E
# C
# I
# S
# I
# O
# N
# ,
#
# O
# t
# h
# e
# r
# ,
#
# m
# e
# m
# b
# e
# r
# s
# ,
#
# i
# n
# ,
#
# m
# y
# ,
#
# p
# a
# r
# t
# y
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# s
# p
# i
# n
# a
# c
# h
# ,
#
# p
# a
# s
# t
# a
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# n
# o
# t
# ,
#
# m
# a
# t
# c
# h
# ,
#
# u
# p
# ,
#
# t
# o
# ,
#
# t
# h
# e
# ,
#
# s
# a
# l
# m
# o
# n
# ,
#
# I
# ,
#
# a
# m
# ,
#
# a
# n
# ,
#
# I
# t
# a
# l
# i
# a
# n
# ,
#
# f
# o
# o
# d
# ,
#
# f
# a
# n
# a
# t
# i
# c
# ,
#
# a
# n
# ,
#
# I
# t
# a
# l
# i
# a
# n
# ,
#
# f
# o
# o
# d
# ,
#
# f
# a
# n
# a
# t
# i
# c
# ,
#
# ,
# ,
#
# s
# o
# ,
#
# I
# ,
#
# s
# a
# w
# ,
#
# t
# h
# e
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# d
# e
# c
# o
# r
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# d
# e
# c
# o
# r
# ,
#
# a
# n
# d
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# m
# e
# n
# u
# ,
#
# I
# ,
#
# f
# i
# g
# u
# r
# e
# d
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# v
# i
# s
# i
# t
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# t
# o
# ,
#
# v
# i
# s
# i
# t
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# T
# h
# e
# ,
#
# t
# o
# m
# a
# t
# o
# ,
#
# s
# o
# u
# p
# ,
#
# w
# a
# s
# ,
#
# q
# u
# i
# t
# e
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# a
# ,
#
# p
# a
# s
# t
# a
# ,
#
# s
# a
# u
# c
# e
# ,
#
# a
# s
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# a
# l
# s
# o
# ,
#
# f
# i
# l
# l
# e
# d
# ,
#
# w
# i
# t
# h
# ,
#
# c
# h
# e
# e
# s
# e
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# S
# a
# l
# m
# o
# n
# ,
#
# .
# ,
#
# B
# E
# S
# T
# ,
#
# t
# h
# e
# ,
#
# S
# a
# l
# m
# o
# n
# ,
#
# .
# ,
#
# B
# E
# S
# T
# ,
#
# D
# E
# C
# I
# S
# I
# O
# N
# ,
#
# E
# V
# E
# R
# ,
#
# t
# h
# e
# ,
#
# s
# p
# i
# n
# a
# c
# h
# ,
#
# p
# a
# s
# t
# a
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# g
# n
# o
# c
# c
# h
# i
# ,
#
# t
# h
# e
# y
# ,
#
# j
# u
# s
# t
# ,
#
# s
# i
# m
# p
# l
# y
# ,
#
# d
# i
# d
# ,
#
# n
# o
# t
# ,
#
# m
# a
# t
# c
# h
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# d
# e
# f
# i
# n
# i
# t
# e
# l
# y
# ,
#
# r
# e
# c
# o
# m
# m
# e
# n
# d
# ,
#
# t
# h
# e
# ,
#
# L
# e
# m
# o
# n
# ]
#
#
# 1
# 4
#
#
#
#
# [
# g
# o
# o
# d
# ,
#
# d
# a
# t
# e
# ,
#
# s
# p
# o
# t
# ,
#
# .
# ,
#
# S
# a
# d
# l
# y
# ,
#
# ,
# ,
#
# n
# o
# t
# ,
#
# o
# n
# ,
#
# a
# ,
#
# d
# a
# t
# e
# ,
#
# .
# .
# .
# ,
#
# b
# u
# t
# ,
#
# b
# u
# t
# ,
#
# s
# o
# m
# e
# d
# a
# y
# ,
#
# (
# ,
#
# l
# e
# t
# s
# ,
#
# a
# l
# l
# ,
#
# k
# e
# e
# p
# ,
#
# c
# r
# o
# s
# s
# e
# d
# ,
#
# )
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# e
# n
# v
# i
# r
# o
# n
# m
# e
# n
# t
# ,
#
# w
# a
# s
# ,
#
# o
# u
# t
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# a
# n
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# (
# ,
#
# t
# h
# o
# u
# g
# h
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# i
# t
# ,
#
# b
# u
# t
# ,
#
# o
# n
# c
# e
# ,
#
# a
# g
# a
# i
# n
# ,
#
# i
# f
# ,
#
# y
# o
# u
# ,
#
# a
# r
# e
# ,
#
# d
# i
# m
# ,
#
# l
# i
# g
# h
# t
# i
# n
# g
# ,
#
# ,
# ,
#
# t
# h
# i
# s
# ,
#
# i
# s
# ,
#
# t
# h
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# A
# n
# y
# t
# h
# i
# n
# g
# ,
#
# G
# o
# e
# s
# ,
#
# d
# r
# i
# n
# k
# ,
#
# a
# n
# d
# ,
#
# g
# r
# e
# a
# t
# ,
#
# b
# u
# z
# z
# ,
#
# .
# ,
#
# M
# y
# ,
#
# w
# a
# i
# t
# e
# r
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# g
# o
# o
# d
# ,
#
# d
# a
# t
# e
# ,
#
# s
# p
# o
# t
# ,
#
# .
# ,
#
# S
# a
# d
# l
# y
# ,
#
# I
# ,
#
# w
# a
# s
# ,
#
# n
# o
# t
# ,
#
# o
# n
# ,
#
# a
# ,
#
# d
# a
# t
# e
# ,
#
# a
# ,
#
# d
# a
# t
# e
# ,
#
# .
# .
# .
# ,
#
# b
# u
# t
# ,
#
# s
# o
# m
# e
# d
# a
# y
# ,
#
# (
# ,
#
# T
# h
# e
# ,
#
# e
# n
# v
# i
# r
# o
# n
# m
# e
# n
# t
# ,
#
# w
# a
# s
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# c
# u
# t
# e
# ,
#
# a
# n
# d
# ,
#
# Y
# o
# u
# ,
#
# h
# a
# v
# e
# ,
#
# a
# n
# ,
#
# o
# u
# t
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# a
# n
# ,
#
# o
# u
# t
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# a
# n
# d
# ,
#
# a
# n
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# a
# n
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# o
# p
# t
# i
# o
# n
# ,
#
# (
# ,
#
# t
# h
# o
# u
# g
# h
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# a
# ,
#
# b
# i
# t
# ,
#
# c
# r
# o
# w
# d
# e
# d
# ,
#
# a
# n
# d
# ,
#
# a
# ,
#
# b
# i
# t
# ,
#
# c
# r
# o
# w
# d
# e
# d
# ,
#
# a
# n
# d
# ,
#
# d
# a
# r
# k
# ,
#
# .
# .
# .
# ,
#
# y
# o
# u
# ,
#
# a
# r
# e
# ,
#
# o
# n
# ,
#
# a
# ,
#
# d
# a
# t
# e
# ,
#
# w
# i
# t
# h
# ,
#
# a
# ,
#
# d
# a
# t
# e
# ,
#
# w
# i
# t
# h
# ,
#
# s
# o
# m
# e
# o
# n
# e
# ,
#
# t
# h
# a
# t
# ,
#
# n
# e
# e
# d
# s
# ,
#
# s
# o
# m
# e
# o
# n
# e
# ,
#
# t
# h
# a
# t
# ,
#
# n
# e
# e
# d
# s
# ,
#
# t
# h
# e
# ,
#
# d
# i
# m
# ,
#
# l
# i
# g
# h
# t
# i
# n
# g
# ,
#
# t
# h
# e
# ,
#
# d
# i
# m
# ,
#
# l
# i
# g
# h
# t
# i
# n
# g
# ,
#
# ,
# ,
#
# t
# h
# i
# s
# ,
#
# i
# s
# ,
#
# y
# o
# u
# ,
#
# )
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# g
# n
# o
# c
# c
# h
# i
# ,
#
# i
# s
# ,
#
# T
# h
# e
# ,
#
# g
# n
# o
# c
# c
# h
# i
# ,
#
# i
# s
# ,
#
# s
# o
# o
# o
# o
# o
# ,
#
# g
# o
# o
# d
# ,
#
# .
# ,
#
# I
# ,
#
# a
# l
# s
# o
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# A
# n
# y
# t
# h
# i
# n
# g
# ,
#
# G
# o
# e
# s
# ,
#
# t
# h
# e
# ,
#
# A
# n
# y
# t
# h
# i
# n
# g
# ,
#
# G
# o
# e
# s
# ,
#
# d
# r
# i
# n
# k
# ,
#
# a
# n
# d
# ,
#
# l
# o
# v
# e
# d
# ,
#
# i
# t
# ,
#
# .
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# 3
# ,
#
# .
# ,
#
# I
# ,
#
# h
# a
# d
# ,
#
# 3
# ,
#
# .
# ,
#
# S
# o
# ,
#
# y
# o
# u
# ,
#
# y
# o
# u
# ,
#
# k
# n
# o
# .
# .
# .
#
#
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# b
# u
# t
# ,
#
# t
# h
# e
# y
# ,
#
# t
# o
# o
# k
# ,
#
# f
# o
# r
# e
# v
# e
# r
# ,
#
# t
# o
# ,
#
# c
# o
# m
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# "
# ,
#
# T
# h
# e
# ,
#
# P
# a
# p
# e
# r
# ,
#
# F
# o
# x
# ,
#
# "
# ,
#
# t
# h
# e
# y
# ,
#
# t
# o
# o
# k
# ,
#
# f
# o
# r
# e
# v
# e
# r
# ,
#
# t
# o
# ,
#
# c
# o
# m
# e
# ,
#
# o
# u
# t
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# "
# ,
#
# T
# h
# e
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# "
# ,
#
# T
# h
# e
# ,
#
# P
# a
# p
# e
# r
# ,
#
# F
# o
# x
# ,
#
# T
# h
# e
# ,
#
# P
# a
# p
# e
# r
# ,
#
# F
# o
# x
# ,
#
# "
# ,
#
# w
# a
# s
# ,
#
# n
# '
# t
# ]
#
#
# 1
# 5
#
#
#
#
# [
# M
# a
# d
# e
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# s
# ,
#
# o
# n
# ,
#
# O
# p
# e
# n
# ,
#
# T
# a
# b
# l
# e
# ,
#
# a
# n
# d
# ,
#
# o
# f
# f
# e
# r
# ,
#
# w
# a
# t
# e
# r
# ,
#
# f
# o
# r
# ,
#
# w
# h
# a
# t
# ,
#
# f
# e
# l
# t
# ,
#
# l
# i
# k
# e
# ,
#
# r
# o
# u
# g
# h
# ,
#
# s
# t
# a
# r
# t
# ,
#
# .
# ,
#
# A
# f
# t
# e
# r
# ,
#
# a
# s
# k
# i
# n
# g
# ,
#
# t
# h
# e
# ,
#
# c
# a
# m
# e
# ,
#
# t
# o
# ,
#
# t
# a
# k
# e
# ,
#
# o
# u
# r
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# o
# r
# d
# e
# r
# ,
#
# .
# ,
#
# W
# e
# ,
#
# g
# o
# t
# ,
#
# t
# h
# e
# ,
#
# p
# r
# i
# x
# ,
#
# p
# r
# i
# x
# ,
#
# f
# i
# x
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# (
# ,
#
# $
# ,
#
# 2
# 8
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# c
# o
# c
# k
# t
# a
# i
# l
# ,
#
# (
# ,
#
# $
# ,
#
# 2
# 4
# ,
#
# )
# ,
#
# g
# r
# e
# a
# t
# ,
#
# d
# e
# a
# l
# ,
#
# .
# ,
#
# A
# f
# t
# e
# r
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# f
# o
# o
# d
# ,
#
# a
# n
# d
# ,
#
# d
# r
# i
# n
# k
# ,
#
# o
# u
# r
# ,
#
# s
# e
# r
# v
# e
# r
# ,
#
# f
# o
# o
# d
# ,
#
# a
# n
# d
# ,
#
# d
# r
# i
# n
# k
# ,
#
# o
# u
# r
# ,
#
# s
# e
# r
# v
# e
# r
# ,
#
# b
# e
# c
# a
# m
# e
# ,
#
# b
# e
# c
# a
# m
# e
# ,
#
# m
# o
# r
# e
# ,
#
# e
# n
# g
# a
# g
# e
# d
# ,
#
# a
# n
# d
# ,
#
# j
# o
# k
# e
# d
# ,
#
# w
# i
# t
# h
# ,
#
# m
# o
# r
# e
# ,
#
# b
# a
# n
# g
# ,
#
# f
# o
# r
# ,
#
# o
# u
# r
# ,
#
# b
# u
# c
# k
# ,
#
# .
# ,
#
# e
# m
# p
# t
# y
# ,
#
# g
# l
# a
# s
# s
# e
# s
# ,
#
# a
# n
# d
# ,
#
# t
# h
# a
# t
# ,
#
# w
# a
# s
# ,
#
# n
# i
# c
# e
# ,
#
# o
# n
# l
# y
# ,
#
# t
# h
# i
# n
# g
# ,
#
# t
# h
# a
# t
# ,
#
# w
# a
# s
# ,
#
# m
# e
# h
# ,
#
# w
# a
# s
# ,
#
# m
# i
# d
# d
# l
# e
# ,
#
# c
# o
# u
# r
# s
# e
# ,
#
# (
# ,
#
# I
# ,
#
# g
# o
# t
# ,
#
# t
# h
# e
# ,
#
# g
# o
# ,
#
# t
# h
# e
# ,
#
# c
# a
# u
# l
# i
# f
# l
# o
# w
# e
# r
# ,
#
# a
# l
# s
# o
# ,
#
# m
# e
# h
# ,
#
# )
# ,
#
# a
# ,
#
# S
# u
# n
# d
# a
# y
# ,
#
# f
# o
# r
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# w
# i
# t
# h
# ,
#
# a
# ,
#
# a
# ,
#
# f
# r
# i
# e
# n
# d
# ,
#
# .
# ,
#
# M
# a
# d
# e
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# s
# ,
#
# o
# n
# ,
#
# N
# o
# b
# o
# d
# y
# ,
#
# c
# a
# m
# e
# ,
#
# t
# o
# ,
#
# c
# h
# e
# c
# k
# ,
#
# o
# n
# ,
#
# u
# s
# ,
#
# u
# s
# ,
#
# o
# r
# ,
#
# o
# f
# f
# e
# r
# ,
#
# w
# a
# t
# e
# r
# ,
#
# f
# o
# r
# ,
#
# w
# h
# a
# t
# ,
#
# w
# h
# a
# t
# ,
#
# f
# e
# l
# t
# ,
#
# l
# i
# k
# e
# ,
#
# F
# O
# R
# E
# V
# E
# R
# ,
#
# a
# n
# d
# ,
#
# s
# o
# ,
#
# i
# t
# ,
#
# f
# e
# l
# t
# ,
#
# l
# i
# k
# e
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# o
# f
# f
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# o
# f
# f
# ,
#
# t
# o
# ,
#
# a
# ,
#
# r
# o
# u
# g
# h
# ,
#
# a
# ,
#
# r
# o
# u
# g
# h
# ,
#
# s
# t
# a
# r
# t
# ,
#
# .
# ,
#
# A
# f
# t
# e
# r
# ,
#
# a
# s
# k
# i
# n
# g
# ,
#
# t
# h
# e
# ,
#
# h
# o
# s
# t
# e
# s
# s
# ,
#
# t
# o
# ,
#
# s
# e
# n
# d
# ,
#
# o
# v
# e
# r
# ,
#
# o
# u
# r
# ,
#
# W
# e
# ,
#
# g
# o
# t
# ,
#
# t
# h
# e
# ,
#
# p
# r
# i
# x
# ,
#
# f
# i
# x
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# t
# h
# e
# ,
#
# p
# r
# i
# x
# ,
#
# f
# i
# x
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# (
# ,
#
# $
# ,
#
# I
# t
# ,
#
# w
# a
# s
# ,
#
# a
# ,
#
# g
# r
# e
# a
# t
# ,
#
# d
# e
# a
# l
# ,
#
# .
# ,
#
# a
# ,
#
# g
# r
# e
# a
# t
# ,
#
# d
# e
# a
# l
# ,
#
# .
# ,
#
# A
# f
# t
# e
# r
# ,
#
# a
# ,
#
# a
# ,
#
# l
# i
# t
# t
# .
# .
# .
#
#
# 3
#
#
#
#
#
# [
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# g
# r
# e
# a
# t
# ,
#
# !
# ,
#
# w
# o
# r
# k
# s
# ,
#
# t
# h
# e
# ,
#
# w
# h
# o
# l
# e
# ,
#
# f
# l
# o
# o
# r
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# w
# h
# o
# l
# e
# ,
#
# f
# l
# o
# o
# r
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# s
# e
# r
# v
# e
# r
# ,
#
# f
# o
# r
# ,
#
# e
# a
# c
# h
# ,
#
# c
# o
# u
# r
# s
# e
# ,
#
# a
# n
# d
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# y
# ,
#
# k
# e
# p
# t
# ,
#
# t
# h
# e
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# !
# ,
#
# Y
# o
# u
# ,
#
# h
# a
# v
# e
# ,
#
# t
# o
# ,
#
# g
# e
# t
# ,
#
# p
# r
# e
# f
# i
# x
# ,
#
# m
# e
# n
# u
# ,
#
# i
# n
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# o
# ,
#
# g
# e
# t
# ,
#
# o
# r
# d
# e
# r
# ,
#
# t
# o
# ,
#
# g
# e
# t
# ,
#
# t
# h
# e
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# o
# p
# t
# i
# o
# n
# s
# ,
#
# w
# e
# r
# e
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# o
# p
# t
# i
# o
# n
# s
# ,
#
# w
# e
# r
# e
# ,
#
# g
# o
# o
# d
# ,
#
# s
# o
# ,
#
# c
# a
# l
# m
# e
# r
# ,
#
# l
# e
# s
# s
# ,
#
# p
# a
# r
# t
# y
# ,
#
# v
# i
# b
# e
# ,
#
# a
# n
# d
# ,
#
# y
# o
# u
# ,
#
# l
# e
# s
# s
# ,
#
# p
# a
# r
# t
# y
# ,
#
# v
# i
# b
# e
# ,
#
# a
# n
# d
# ,
#
# y
# o
# u
# ,
#
# c
# a
# n
# ,
#
# g
# o
# o
# d
# ,
#
# f
# o
# o
# d
# ,
#
# a
# n
# d
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# !
# ,
#
# !
# ,
#
# a
# ,
#
# S
# a
# t
# u
# r
# d
# a
# y
# ,
#
# f
# o
# r
# ,
#
# t
# h
# e
# i
# r
# ,
#
# b
# o
# t
# t
# o
# m
# l
# e
# s
# s
# ,
#
# b
# r
# u
# n
# c
# h
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# g
# r
# e
# a
# t
# ,
#
# !
# ,
#
# !
# ,
#
# W
# e
# ,
#
# W
# e
# ,
#
# w
# e
# r
# e
# ,
#
# r
# u
# n
# n
# i
# n
# g
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# l
# a
# t
# e
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# l
# a
# t
# e
# ,
#
# f
# o
# r
# ,
#
# o
# u
# r
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# t
# h
# e
# y
# ,
#
# s
# t
# i
# l
# l
# ,
#
# s
# a
# t
# ,
#
# u
# s
# ,
#
# r
# i
# g
# h
# t
# ,
#
# w
# h
# e
# n
# ,
#
# u
# s
# ,
#
# r
# i
# g
# h
# t
# ,
#
# w
# h
# e
# n
# ,
#
# w
# e
# ,
#
# g
# o
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# w
# e
# ,
#
# g
# o
# t
# ,
#
# t
# h
# e
# r
# e
# ,
#
# .
# ,
#
# E
# v
# e
# r
# y
# o
# n
# e
# ,
#
# w
# a
# s
# ,
#
# E
# v
# e
# r
# y
# o
# n
# e
# ,
#
# w
# a
# s
# ,
#
# n
# i
# c
# e
# ,
#
# ,
# ,
#
# I
# ,
#
# f
# e
# e
# l
# ,
#
# I
# ,
#
# f
# e
# e
# l
# ,
#
# l
# i
# k
# e
# ,
#
# t
# h
# e
# ,
#
# s
# t
# a
# f
# f
# ,
#
# w
# o
# r
# k
# s
# ,
#
# t
# h
# e
# ,
#
# w
# h
# o
# l
# e
# ,
#
# f
# l
# o
# o
# r
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# s
# e
# r
# v
# e
# r
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# s
# e
# r
# v
# e
# r
# ,
#
# f
# o
# r
# ,
#
# e
# a
# c
# h
# ,
#
# c
# o
# u
# r
# s
# e
# ,
#
# t
# h
# e
# y
# ,
#
# k
# e
# p
# t
# ,
#
# t
# h
# e
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# !
# ,
#
# t
# h
# e
# ,
#
# d
# r
# i
# n
# k
# s
# ,
#
# c
# o
# m
# i
# n
# g
# ,
#
# !
# ,
#
# Y
# o
# u
# ,
#
# h
# a
# v
# e
# ,
#
# Y
# o
# u
# ,
#
# h
# a
# v
# e
# ,
#
# t
# o
# ,
#
# g
# e
# t
# ,
#
# .
# .
# .
#
#
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# b
# u
# t
# ,
#
# s
# a
# t
# ,
#
# a
# n
# y
# w
# a
# y
# ,
#
# w
# h
# i
# l
# e
# ,
#
# I
# ,
#
# w
# a
# i
# t
# e
# d
# ,
#
# w
# a
# i
# t
# e
# d
# ,
#
# f
# o
# r
# ,
#
# m
# y
# ,
#
# d
# i
# n
# n
# e
# r
# ,
#
# p
# a
# r
# t
# n
# e
# r
# ,
#
# .
# ,
#
# w
# a
# i
# t
# e
# d
# ,
#
# a
# n
# d
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# .
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# .
# ,
#
# A
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# b
# u
# t
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# M
# a
# n
# h
# a
# t
# t
# a
# n
# ,
#
# .
# ,
#
# W
# a
# i
# t
# r
# e
# s
# s
# ,
#
# I
# ,
#
# w
# a
# i
# t
# e
# d
# ,
#
# f
# o
# r
# ,
#
# m
# y
# ,
#
# d
# i
# n
# n
# e
# r
# ,
#
# p
# a
# r
# t
# n
# e
# r
# ,
#
# I
# ,
#
# w
# a
# i
# t
# e
# d
# ,
#
# a
# n
# d
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# .
# ,
#
# A
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# r
# i
# c
# e
# y
# ,
#
# A
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# r
# i
# c
# e
# y
# ,
#
# b
# u
# t
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# i
# t
# ,
#
# '
# s
# ,
#
# M
# a
# n
# h
# a
# t
# t
# a
# n
# ,
#
# .
# ,
#
# W
# a
# i
# t
# r
# e
# s
# s
# ,
#
# w
# a
# s
# ]
#
#
# 6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# A
# w
# e
# s
# o
# m
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# !
# ,
#
# T
# h
# e
# ,
#
# b
# a
# r
# t
# e
# n
# d
# e
# r
# ,
#
# w
# a
# s
# ,
#
# M
# a
# n
# y
# ,
#
# p
# e
# o
# p
# l
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# c
# o
# c
# k
# t
# a
# i
# l
# s
# ,
#
# w
# h
# i
# c
# h
# ,
#
# B
# e
# a
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# c
# o
# c
# k
# t
# a
# i
# l
# s
# ,
#
# w
# h
# i
# c
# h
# ,
#
# B
# e
# a
# ,
#
# s
# e
# e
# m
# s
# ,
#
# t
# o
# ,
#
# m
# u
# s
# t
# ,
#
# l
# o
# v
# e
# ,
#
# t
# h
# i
# s
# ,
#
# p
# l
# a
# c
# e
# ,
#
# a
# s
# ,
#
# w
# e
# l
# l
# ,
#
# I
# ,
#
# s
# a
# t
# ,
#
# a
# t
# ,
#
# t
# h
# e
# ,
#
# b
# a
# r
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# d
# r
# i
# n
# k
# ,
#
# a
# n
# d
# ,
#
# a
# ,
#
# b
# i
# t
# e
# ,
#
# a
# f
# t
# e
# r
# ,
#
# a
# ,
#
# b
# i
# t
# e
# ,
#
# a
# f
# t
# e
# r
# ,
#
# v
# i
# s
# i
# t
# i
# n
# g
# ,
#
# N
# Y
# C
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# s
# h
# o
# w
# ,
#
# .
# ,
#
# A
# w
# e
# s
# o
# m
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# !
# ,
#
# T
# h
# e
# ,
#
# b
# a
# r
# t
# e
# n
# d
# e
# r
# ,
#
# w
# a
# s
# ,
#
# i
# m
# p
# r
# e
# s
# s
# i
# v
# e
# l
# y
# ,
#
# a
# t
# t
# e
# n
# t
# i
# v
# e
# ,
#
# a
# n
# d
# ,
#
# W
# e
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# e
# ,
#
# d
# r
# a
# f
# t
# ,
#
# b
# e
# e
# r
# s
# ,
#
# ,
# ,
#
# t
# h
# e
# ,
#
# d
# r
# a
# f
# t
# ,
#
# b
# e
# e
# r
# s
# ,
#
# ,
# ,
#
# r
# i
# c
# o
# t
# t
# a
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# ,
#
# T
# h
# e
# ,
#
# p
# l
# a
# c
# e
# ,
#
# w
# a
# s
# ,
#
# v
# e
# r
# y
# ,
#
# b
# u
# s
# y
# ,
#
# a
# t
# ,
#
# a
# ,
#
# S
# a
# t
# u
# r
# d
# a
# y
# ,
#
# s
# o
# ,
#
# o
# t
# h
# e
# r
# s
# ,
#
# m
# u
# s
# t
# ,
#
# l
# o
# v
# e
# ]
#
#
# 1
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
#
# ,
#
# K
# a
# l
# e
# ,
#
# s
# a
# l
# a
# d
# ,
#
# t
# o
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
#
# ,
#
# K
# a
# l
# e
# ,
#
# s
# a
# l
# a
# d
# ,
#
# t
# h
# e
# ,
#
#
# ,
#
# K
# a
# l
# e
# ,
#
# s
# a
# l
# a
# d
# ,
#
# t
# o
# ,
#
# b
# e
# g
# i
# n
# ,
#
# t
# h
# e
# ,
#
# C
# h
# i
# l
# e
# a
# n
# ,
#
# S
# e
# a
# ,
#
# b
# a
# s
# s
# ,
#
# .
# ,
#
# B
# o
# t
# h
# ]
#
#
# 1
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# n
# o
# t
# ,
#
# l
# i
# e
# ,
#
# .
# ,
#
# T
# h
# i
# s
# ,
#
# p
# l
# a
# c
# e
# ,
#
# h
# a
# s
# ,
#
# g
# r
# e
# a
# t
# ,
#
# v
# i
# b
# e
# ,
#
# a
# n
# d
# ,
#
# e
# v
# e
# n
# ,
#
# b
# e
# t
# t
# e
# r
# ,
#
# c
# o
# c
# k
# t
# a
# i
# l
# s
# ,
#
# b
# e
# t
# t
# e
# r
# ,
#
# c
# o
# c
# k
# t
# a
# i
# l
# s
# ,
#
# .
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# L
# a
# v
# e
# n
# d
# e
# r
# ,
#
# M
# o
# n
# k
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# T
# h
# e
# ,
#
# r
# e
# v
# i
# e
# w
# s
# ,
#
# f
# o
# r
# ,
#
# B
# e
# a
# ,
#
# d
# o
# ,
#
# n
# o
# t
# ,
#
# a
# ,
#
# g
# r
# e
# a
# t
# ,
#
# v
# i
# b
# e
# ,
#
# a
# n
# d
# ,
#
# e
# v
# e
# n
# ,
#
# b
# e
# t
# t
# e
# r
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# L
# a
# v
# e
# n
# d
# e
# r
# ,
#
# M
# o
# n
# k
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# L
# a
# v
# e
# n
# d
# e
# r
# ,
#
# M
# o
# n
# k
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ]
#
#
# 1
# 6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# o
# r
# d
# e
# r
# e
# d
# ,
#
# S
# p
# i
# c
# y
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# ,
# ,
#
# s
# o
# ,
#
# p
# a
# i
# r
# e
# d
# ,
#
# w
# i
# t
# h
# ,
#
# w
# i
# n
# e
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# f
# o
# r
# ,
#
# l
# a
# s
# t
# ,
#
# s
# p
# a
# r
# k
# l
# i
# n
# g
# ,
#
# r
# o
# s
# e
# ,
#
# ,
# ,
#
# e
# m
# p
# l
# o
# y
# e
# e
# s
# ,
#
# a
# r
# e
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# S
# p
# i
# c
# y
# ,
#
# l
# a
# m
# b
# ,
#
# m
# e
# a
# t
# b
# a
# l
# l
# s
# ,
#
# ,
# ,
#
# I
# ,
#
# w
# i
# l
# l
# ,
#
# d
# e
# f
# i
# n
# i
# t
# e
# l
# y
# ,
#
# g
# o
# i
# n
# g
# ,
#
# b
# a
# c
# k
# ,
#
# ,
# ]
#
#
# 1
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# f
# i
# r
# s
# t
# ,
#
# d
# a
# y
# ,
#
# o
# f
# ,
#
# t
# h
# e
# i
# r
# ,
#
# v
# a
# c
# a
# t
# i
# o
# n
# ,
#
# v
# i
# s
# i
# t
# i
# n
# g
# ,
#
# v
# i
# s
# i
# t
# i
# n
# g
# ,
#
# m
# e
# ,
#
# i
# n
# ,
#
# t
# h
# e
# ,
#
# c
# i
# t
# y
# ,
#
# .
# ,
#
# a
# t
# t
# e
# n
# t
# i
# v
# e
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# ,
# ,
#
# i
# m
# p
# r
# e
# s
# s
# i
# v
# e
# ,
#
# e
# n
# t
# e
# r
# t
# a
# i
# n
# m
# e
# n
# t
# ,
#
# w
# i
# t
# h
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# ,
# ,
#
# i
# m
# p
# r
# e
# s
# s
# i
# v
# e
# ,
#
# e
# n
# t
# e
# r
# t
# a
# i
# n
# m
# e
# n
# t
# ,
#
# w
# i
# t
# h
# ,
#
# 2
# ,
#
# i
# m
# p
# r
# e
# s
# s
# i
# v
# e
# ,
#
# e
# n
# t
# e
# r
# t
# a
# i
# n
# m
# e
# n
# t
# ,
#
# w
# i
# t
# h
# ,
#
# 2
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# f
# i
# l
# m
# s
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# f
# i
# l
# m
# s
# ,
#
# p
# r
# o
# j
# e
# c
# t
# e
# d
# ,
#
# o
# n
# ,
#
# o
# p
# p
# o
# s
# i
# n
# g
# ,
#
# w
# a
# l
# l
# s
# ,
#
# p
# r
# o
# j
# e
# c
# t
# e
# d
# ,
#
# o
# n
# ,
#
# o
# p
# p
# o
# s
# i
# n
# g
# ,
#
# w
# a
# l
# l
# s
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# o
# p
# p
# o
# s
# i
# n
# g
# ,
#
# w
# a
# l
# l
# s
# ,
#
# ,
# ,
#
# a
# n
# d
# ,
#
# e
# x
# c
# e
# l
# l
# e
# n
# t
# ,
#
# f
# o
# o
# d
# ,
#
# e
# x
# c
# e
# l
# l
# e
# n
# t
# ,
#
# f
# o
# o
# d
# ,
#
# .
# ,
#
# M
# y
# ,
#
# f
# a
# t
# h
# e
# r
# ,
#
# '
# s
# ,
#
# f
# o
# o
# d
# ,
#
# .
# ,
#
# M
# y
# ,
#
# f
# a
# t
# h
# e
# r
# ,
#
# '
# s
# ,
#
# a
# ,
#
# p
# i
# c
# k
# y
# ,
#
# e
# a
# t
# e
# r
# ,
#
# b
# u
# t
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# b
# u
# t
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# c
# h
# o
# p
# s
# ,
#
# w
# i
# t
# h
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# s
# a
# l
# a
# d
# ,
#
# w
# i
# t
# h
# ,
#
# s
# a
# l
# m
# o
# n
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# t
# o
# o
# k
# ,
#
# m
# y
# ,
#
# p
# a
# r
# e
# n
# t
# s
# ,
#
# t
# o
# ,
#
# t
# h
# i
# s
# ,
#
# m
# e
# ,
#
# i
# n
# ,
#
# t
# h
# e
# ,
#
# c
# i
# t
# y
# ,
#
# .
# ,
#
# T
# h
# e
# y
# ,
#
# T
# h
# e
# y
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# i
# s
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# ,
#
# :
# ,
#
# g
# r
# e
# a
# t
# ,
#
# a
# ,
#
# p
# i
# c
# k
# y
# ,
#
# e
# a
# t
# e
# r
# ,
#
# b
# u
# t
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# e
# ,
#
# t
# h
# e
# ,
#
# l
# a
# m
# b
# ,
#
# c
# h
# o
# p
# s
# ,
#
# w
# i
# t
# h
# ,
#
# z
# u
# c
# c
# h
# i
# n
# i
# ,
#
# .
# ,
#
# I
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# s
# a
# l
# a
# d
# ,
#
# w
# i
# t
# h
# ,
#
# s
# a
# l
# m
# o
# n
# ,
#
# a
# ,
#
# s
# a
# l
# a
# d
# ,
#
# w
# i
# t
# h
# ,
#
# s
# a
# l
# m
# o
# n
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# s
# u
# p
# e
# r
# b
# ,
#
# .
# ,
#
# I
# ,
#
# l
# o
# o
# k
# ,
#
# I
# ,
#
# l
# o
# o
# k
# ,
#
# f
# o
# r
# w
# a
# r
# d
# ,
#
# t
# o
# ,
#
# t
# r
# y
# i
# n
# g
# ,
#
# o
# t
# h
# e
# r
# ]
#
#
# 1
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# D
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# f
# o
# o
# d
# ,
#
# ,
# ,
#
# c
# o
# o
# l
# ,
#
# "
# ,
#
# h
# i
# p
# s
# t
# e
# r
# ,
#
# f
# o
# o
# d
# ,
#
# ,
# ,
#
# c
# o
# o
# l
# ,
#
# "
# ,
#
# h
# i
# p
# s
# t
# e
# r
# ,
#
# v
# i
# b
# e
# ,
#
# o
# r
# d
# e
# r
# ,
#
# ,
# ,
#
# i
# f
# ,
#
# y
# o
# u
# ,
#
# l
# i
# k
# e
# ,
#
# t
# o
# ,
#
# g
# r
# e
# a
# t
# ,
#
# p
# l
# a
# c
# e
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# f
# i
# r
# s
# t
# ,
#
# d
# a
# t
# e
# ,
#
# f
# i
# r
# s
# t
# ,
#
# d
# a
# t
# e
# ,
#
# o
# r
# ,
#
# a
# n
# n
# i
# v
# e
# r
# s
# a
# r
# y
# ,
#
# .
# ,
#
# O
# n
# e
# ,
#
# f
# e
# w
# ,
#
# p
# l
# a
# c
# e
# s
# ,
#
# I
# ,
#
# '
# v
# e
# ,
#
# f
# o
# u
# n
# d
# ,
#
# a
# ,
#
# p
# r
# i
# c
# e
# d
# ,
#
# m
# e
# a
# t
# ,
#
# a
# n
# d
# ,
#
# c
# h
# e
# e
# s
# e
# ,
#
# b
# o
# a
# r
# d
# ,
#
# i
# n
# ,
#
# y
# o
# u
# ,
#
# l
# i
# k
# e
# ,
#
# t
# o
# ,
#
# k
# e
# e
# p
# ,
#
# i
# t
# ,
#
# b
# a
# s
# i
# c
# ,
#
# i
# t
# ,
#
# b
# a
# s
# i
# c
# ,
#
# o
# r
# ,
#
# d
# a
# r
# e
# ,
#
# t
# o
# ,
#
# t
# r
# y
# ,
#
# s
# o
# m
# e
# t
# h
# i
# n
# g
# ,
#
# n
# e
# w
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# c
# o
# u
# r
# t
# y
# a
# r
# d
# ,
#
# i
# s
# ,
#
# T
# h
# e
# ,
#
# c
# o
# u
# r
# t
# y
# a
# r
# d
# ,
#
# i
# s
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# a
# n
# d
# ,
#
# a
# ,
#
# a
# ,
#
# g
# r
# e
# a
# t
# ,
#
# p
# l
# a
# c
# e
# ,
#
# f
# o
# r
# ,
#
# a
# ,
#
# f
# i
# r
# s
# t
# ,
#
# a
# ,
#
# f
# i
# r
# s
# t
# ,
#
# d
# a
# t
# e
# ,
#
# o
# r
# ,
#
# a
# n
# n
# i
# v
# e
# r
# s
# a
# r
# y
# ,
#
# .
# ,
#
# I
# ,
#
# '
# v
# e
# ,
#
# f
# o
# u
# n
# d
# ,
#
# a
# ,
#
# r
# e
# a
# s
# o
# n
# a
# b
# l
# y
# ,
#
# p
# r
# i
# c
# e
# d
# ,
#
# a
# ,
#
# r
# e
# a
# s
# o
# n
# a
# b
# l
# y
# ,
#
# p
# r
# i
# c
# e
# d
# ,
#
# m
# e
# a
# t
# ,
#
# a
# n
# d
# ,
#
# c
# h
# e
# e
# s
# e
# ]
#
#
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# c
# o
# n
# f
# i
# d
# e
# n
# t
# ,
#
# f
# o
# o
# d
# ,
#
# o
# r
# d
# e
# r
# ,
#
# d
# e
# c
# i
# s
# i
# o
# n
# ,
#
# .
# ,
#
# P
# i
# e
# r
# ,
#
# f
# o
# o
# d
# ,
#
# o
# r
# d
# e
# r
# ,
#
# d
# e
# c
# i
# s
# i
# o
# n
# ,
#
# .
# ,
#
# P
# i
# e
# r
# ,
#
# i
# s
# ,
#
# o
# r
# d
# e
# r
# ,
#
# d
# e
# c
# i
# s
# i
# o
# n
# ,
#
# .
# ,
#
# P
# i
# e
# r
# ,
#
# i
# s
# ,
#
# a
# ,
#
# l
# e
# t
# ,
#
# m
# a
# n
# a
# g
# e
# m
# e
# n
# t
# ,
#
# k
# n
# o
# w
# ,
#
# t
# o
# ,
#
# a
# l
# l
# o
# w
# ,
#
# t
# h
# i
# s
# ,
#
# k
# n
# o
# w
# ,
#
# t
# o
# ,
#
# a
# l
# l
# o
# w
# ,
#
# t
# h
# i
# s
# ,
#
# g
# e
# n
# t
# l
# e
# m
# a
# n
# ,
#
# t
# o
# ,
#
# t
# h
# e
# ,
#
# l
# e
# a
# s
# t
# ,
#
# .
# ,
#
# S
# h
# e
# ,
#
# a
# n
# s
# w
# e
# r
# e
# d
# ,
#
# a
# l
# l
# ,
#
# S
# h
# e
# ,
#
# a
# n
# s
# w
# e
# r
# e
# d
# ,
#
# a
# l
# l
# ,
#
# m
# y
# ,
#
# q
# u
# e
# s
# t
# i
# o
# n
# s
# ,
#
# w
# i
# t
# h
# ,
#
# m
# e
# ,
#
# t
# o
# ,
#
# m
# a
# k
# e
# ,
#
# a
# ,
#
# c
# o
# n
# f
# i
# d
# e
# n
# t
# ,
#
# f
# o
# o
# d
# ,
#
# a
# ,
#
# c
# o
# n
# f
# i
# d
# e
# n
# t
# ,
#
# f
# o
# o
# d
# ,
#
# o
# r
# d
# e
# r
# ,
#
# d
# e
# c
# i
# s
# i
# o
# n
# ,
#
# .
# ,
#
# a
# ,
#
# w
# i
# n
# n
# e
# r
# ,
#
# w
# i
# t
# h
# i
# n
# ,
#
# t
# h
# e
# ,
#
# c
# o
# m
# p
# a
# n
# y
# ,
#
# ,
# ,
#
# a
# ,
#
# a
# l
# l
# ,
#
# -
# ,
#
# a
# r
# o
# u
# n
# d
# ,
#
# w
# i
# n
# n
# e
# r
# ,
#
# ,
# ,
#
# a
# ,
#
# m
# o
# r
# e
# ,
#
# t
# h
# a
# n
# ,
#
# p
# e
# r
# f
# e
# c
# t
# ,
#
# a
# t
# t
# i
# t
# u
# d
# e
# ,
#
# .
# ]
#
#
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# e
# n
# t
# r
# e
# e
# ,
#
# a
# n
# d
# ,
#
# n
# o
# t
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# e
# n
# t
# r
# e
# e
# ,
#
# a
# n
# d
# ,
#
# n
# o
# t
# ,
#
# o
# n
# e
# ,
#
# o
# f
# ,
#
# n
# o
# t
# ,
#
# o
# n
# e
# ,
#
# o
# f
# ,
#
# u
# s
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# s
# u
# n
# r
# o
# o
# m
# ,
#
# o
# f
# f
# ,
#
# t
# h
# e
# ,
#
# b
# a
# r
# ,
#
# b
# u
# t
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# ,
#
# b
# a
# r
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# g
# o
# o
# d
# ,
#
# g
# o
# o
# d
# ,
#
# v
# i
# b
# e
# ,
#
# g
# o
# i
# n
# g
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# .
# ,
#
# I
# t
# ,
#
# g
# o
# i
# n
# g
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# .
# ,
#
# I
# t
# ,
#
# '
# s
# ,
#
# a
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# n
# ,
#
# a
# g
# a
# i
# n
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# h
# a
# v
# e
# ,
#
# f
# a
# i
# r
# ,
#
# a
# m
# o
# u
# n
# t
# ,
#
# o
# f
# ,
#
# w
# i
# n
# e
# ,
#
# b
# e
# t
# w
# e
# e
# n
# ,
#
# a
# l
# l
# ,
#
# g
# o
# o
# d
# ,
#
# n
# i
# g
# h
# t
# ,
#
# o
# u
# t
# ,
#
# o
# r
# ,
#
# a
# f
# t
# e
# r
# ,
#
# /
# ,
#
# a
# ,
#
# g
# r
# o
# u
# p
# ,
#
# o
# f
# ,
#
# 8
# ,
#
# g
# i
# r
# l
# s
# ,
#
# a
# f
# t
# e
# r
# ,
#
# a
# ,
#
# s
# h
# o
# w
# ,
#
# o
# n
# ,
#
# b
# r
# o
# a
# d
# w
# a
# y
# ,
#
# a
# n
# d
# ,
#
# w
# e
# ,
#
# w
# e
# ,
#
# c
# o
# u
# l
# d
# ,
#
# n
# '
# t
# ,
#
# h
# a
# v
# e
# ,
#
# l
# o
# v
# e
# d
# ,
#
# i
# t
# ,
#
# i
# t
# ,
#
# m
# o
# r
# e
# ,
#
# .
# ,
#
# O
# u
# r
# ,
#
# w
# a
# i
# t
# r
# e
# s
# s
# ,
#
# w
# a
# s
# ,
#
# W
# e
# ,
#
# e
# a
# c
# h
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# e
# n
# t
# r
# e
# e
# ,
#
# a
# ,
#
# d
# i
# f
# f
# e
# r
# e
# n
# t
# ,
#
# e
# n
# t
# r
# e
# e
# ,
#
# a
# n
# d
# ,
#
# n
# o
# t
# ,
#
# o
# n
# e
# ,
#
# u
# s
# ,
#
# h
# a
# d
# ,
#
# a
# ,
#
# c
# o
# m
# p
# l
# a
# i
# n
# t
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# a
# ,
#
# c
# o
# m
# p
# l
# a
# i
# n
# t
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# w
# e
# r
# e
# ,
#
# T
# h
# e
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# w
# e
# r
# e
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# a
# n
# d
# ,
#
# w
# i
# n
# e
# ,
#
# W
# e
# ,
#
# w
# e
# r
# e
# ,
#
# s
# i
# t
# t
# i
# n
# g
# ,
#
# i
# n
# ,
#
# a
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# a
# ,
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# ,
#
# s
# u
# n
# r
# o
# o
# m
# ,
#
# o
# f
# f
# ,
#
# t
# h
# e
# ,
#
# b
# a
# r
# ,
#
# a
# ,
#
# g
# o
# o
# d
# ,
#
# v
# i
# b
# e
# ,
#
# g
# o
# i
# n
# g
# ,
#
# i
# n
# s
# i
# d
# e
# ,
#
# .
# ,
#
# I
# t
# ,
#
# '
# s
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# r
# i
# c
# e
# y
# ,
#
# b
# u
# t
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# p
# r
# i
# c
# e
# y
# ,
#
# b
# u
# t
# ,
#
# t
# h
# e
# n
# ,
#
# a
# g
# a
# i
# n
# ,
#
# w
# e
# ,
#
# d
# i
# d
# ,
#
# h
# a
# v
# e
# ,
#
# a
# ,
#
# f
# a
# i
# r
# ,
#
# a
# m
# o
# u
# n
# t
# ,
#
# a
# ,
#
# f
# a
# i
# r
# ,
#
# a
# m
# o
# u
# n
# t
# ,
#
# o
# f
# ,
#
# w
# i
# n
# e
# ,
#
# b
# e
# t
# w
# e
# e
# n
# ,
#
# a
# ,
#
# g
# o
# o
# d
# ,
#
# n
# i
# g
# h
# t
# ,
#
# o
# u
# t
# ,
#
# o
# r
# ,
#
# a
# f
# t
# e
# r
# ]
#
#
# 4
#
#
#
#
#
# [
# g
# r
# e
# a
# t
# ,
#
# r
# e
# v
# i
# e
# w
# s
# ,
#
# .
# ,
#
# W
# e
# ,
#
# d
# i
# d
# ,
#
# m
# a
# k
# e
# ,
#
# m
# a
# k
# e
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# s
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# s
# t
# r
# o
# n
# g
# l
# y
# ,
#
# t
# o
# o
# k
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# b
# i
# t
# ,
#
# t
# o
# ,
#
# c
# o
# m
# e
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# b
# i
# t
# ,
#
# t
# o
# ,
#
# c
# o
# m
# e
# ,
#
# o
# v
# e
# r
# ,
#
# ,
# ,
#
# b
# u
# t
# ,
#
# o
# n
# c
# e
# ,
#
# t
# h
# e
# y
# ,
#
# d
# i
# d
# ,
#
# ,
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# w
# a
# s
# ,
#
# i
# m
# p
# e
# c
# c
# a
# b
# l
# e
# ,
#
# .
# ,
#
# I
# t
# ,
#
# w
# a
# s
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# b
# y
# ,
#
# c
# o
# m
# m
# i
# t
# t
# e
# e
# ,
#
# a
# n
# d
# ,
#
# e
# v
# e
# r
# y
# o
# n
# e
# ,
#
# o
# f
# ,
#
# f
# o
# o
# d
# ,
#
# .
# ,
#
# W
# e
# ,
#
# s
# t
# a
# r
# t
# e
# d
# ,
#
# w
# i
# t
# h
# ,
#
# t
# o
# m
# a
# t
# o
# ,
#
# p
# l
# e
# a
# s
# a
# n
# t
# ,
#
# t
# a
# s
# t
# e
# ,
#
# a
# n
# d
# ,
#
# t
# h
# e
# ,
#
# t
# e
# x
# t
# u
# r
# e
# ,
#
# w
# a
# s
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# f
# a
# t
# t
# y
# ,
#
# ,
# ,
#
# b
# u
# t
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# !
# ,
#
# b
# u
# t
# ,
#
# d
# e
# l
# i
# c
# i
# o
# u
# s
# ,
#
# !
# ,
#
# P
# o
# t
# a
# t
# o
# e
# s
# ,
#
# a
# n
# d
# ,
#
# v
# e
# g
# ,
#
# b
# u
# t
# ,
#
# t
# h
# a
# t
# ,
#
# i
# s
# ,
#
# b
# e
# i
# n
# g
# ,
#
# v
# e
# r
# y
# ,
#
# p
# i
# c
# k
# y
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# t
# h
# e
# ,
#
# A
# n
# y
# t
# h
# i
# n
# g
# ,
#
# G
# o
# e
# s
# ,
#
# a
# n
# d
# ,
#
# i
# t
# ,
#
# I
# ,
#
# m
# u
# s
# t
# ,
#
# s
# a
# y
# ,
#
# ,
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# w
# e
# ,
#
# w
# e
# r
# e
# ,
#
# e
# x
# c
# i
# t
# e
# d
# ,
#
# t
# o
# ,
#
# t
# r
# y
# ,
#
# t
# h
# i
# s
# ,
#
# I
# t
# ,
#
# l
# o
# o
# k
# e
# d
# ,
#
# l
# i
# k
# e
# ,
#
# a
# ,
#
# l
# o
# t
# ,
#
# o
# f
# ,
#
# a
# ,
#
# l
# o
# t
# ,
#
# o
# f
# ,
#
# g
# r
# e
# a
# t
# ,
#
# r
# e
# v
# i
# e
# w
# s
# ,
#
# .
# ,
#
# W
# e
# ,
#
# d
# i
# d
# ,
#
# m
# a
# k
# e
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# s
# ,
#
# a
# n
# d
# ,
#
# I
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# s
# t
# r
# o
# n
# g
# l
# y
# ,
#
# r
# e
# c
# o
# m
# m
# e
# n
# d
# ,
#
# .
# ,
#
# M
# y
# ,
#
# I
# ,
#
# w
# e
# r
# e
# ,
#
# s
# e
# a
# t
# i
# n
# g
# ,
#
# i
# n
# ,
#
# t
# h
# e
# ,
#
# A
# t
# r
# i
# u
# m
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# r
# a
# i
# n
# i
# n
# g
# ,
#
# a
# n
# d
# ,
#
# g
# l
# o
# o
# m
# y
# ,
#
# )
# ,
#
# T
# h
# e
# ,
#
# s
# e
# r
# v
# e
# r
# s
# ,
#
# t
# o
# o
# k
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# b
# i
# t
# ,
#
# a
# ,
#
# l
# i
# t
# t
# l
# e
# ,
#
# b
# i
# t
# ,
#
# t
# o
# ,
#
# c
# o
# m
# e
# ,
#
# o
# v
# e
# r
# ,
#
# t
# h
# e
# y
# ,
#
# d
# i
# d
# ,
#
# ,
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# w
# a
# s
# ,
#
# i
# m
# p
# e
# c
# c
# a
# b
# l
# e
# ,
#
# I
# t
# ,
#
# w
# a
# s
# ,
#
# m
# o
# r
# e
# ,
#
# o
# f
# ,
#
# a
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# a
# ,
#
# s
# e
# r
# v
# i
# c
# e
# ,
#
# b
# y
# ,
#
# c
# o
# m
# m
# i
# t
# t
# e
# e
# ,
#
# a
# n
# d
# ,
#
# e
# v
# e
# r
# y
# o
# n
# e
# ,
#
# e
# v
# e
# r
# y
# o
# n
# e
# ,
#
# o
# f
# ,
#
# t
# h
# e
# ,
#
# t
# e
# a
# m
# ,
#
# w
# a
# s
# ,
#
# p
# l
# e
# a
# s
# a
# n
# t
# ,
#
# '
# s
# ,
#
# g
# o
# ,
#
# t
# o
# ,
#
# t
# h
# e
# ,
#
# f
# o
# o
# d
# ,
#
# .
# .
# .
#
#
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# f
# a
# v
# o
# r
# i
# t
# e
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# ,
#
# o
# f
# ,
#
# o
# u
# r
# ,
#
# N
# e
# w
# ,
#
# Y
# o
# r
# k
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# v
# a
# r
# i
# e
# t
# y
# ,
#
# o
# f
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# ,
# ,
#
# w
# a
# i
# t
# ,
#
# s
# t
# a
# f
# f
# ,
#
# w
# a
# s
# ,
#
# p
# o
# l
# i
# t
# e
# ,
#
# a
# n
# d
# ,
#
# a
# t
# t
# e
# n
# t
# i
# v
# e
# ,
#
# B
# e
# s
# t
# ,
#
# p
# a
# r
# t
# ,
#
# w
# a
# s
# ,
#
# t
# h
# e
# ,
#
# l
# o
# c
# a
# t
# i
# o
# n
# ,
#
# l
# o
# c
# a
# t
# e
# d
# ,
#
# l
# o
# c
# a
# t
# e
# d
# ,
#
# a
# ,
#
# f
# e
# w
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# w
# a
# l
# k
# ,
#
# f
# r
# o
# m
# ,
#
# f
# e
# w
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# w
# a
# l
# k
# ,
#
# f
# r
# o
# m
# ,
#
# a
# l
# l
# ,
#
# t
# h
# e
# ,
#
# w
# a
# l
# k
# ,
#
# f
# r
# o
# m
# ,
#
# a
# l
# l
# ,
#
# t
# h
# e
# ,
#
# B
# r
# o
# a
# d
# w
# a
# y
# ,
#
# s
# h
# o
# w
# s
# ,
#
# W
# e
# ,
#
# a
# l
# l
# ,
#
# a
# g
# r
# e
# e
# d
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# o
# u
# r
# ,
#
# i
# t
# ,
#
# w
# a
# s
# ,
#
# o
# u
# r
# ,
#
# f
# a
# v
# o
# r
# i
# t
# e
# ,
#
# r
# e
# s
# t
# a
# u
# r
# a
# n
# t
# ,
#
# o
# f
# ,
#
# W
# e
# ,
#
# m
# a
# d
# e
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# ,
# ,
#
# w
# h
# i
# c
# h
# ,
#
# a
# ,
#
# r
# e
# s
# e
# r
# v
# a
# t
# i
# o
# n
# ,
#
# ,
# ,
#
# w
# h
# i
# c
# h
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# I
# ,
#
# w
# o
# u
# l
# d
# ,
#
# r
# e
# c
# o
# m
# m
# e
# n
# d
# ,
#
# o
# n
# ,
#
# a
# ,
#
# w
# e
# e
# k
# e
# n
# d
# ,
#
# a
# ,
#
# w
# e
# e
# k
# e
# n
# d
# ,
#
# .
# ,
#
# W
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# W
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# a
# ,
#
# v
# a
# r
# i
# e
# t
# y
# ,
#
# o
# f
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# a
# ,
#
# v
# a
# r
# i
# e
# t
# y
# ,
#
# o
# f
# ,
#
# a
# p
# p
# e
# t
# i
# z
# e
# r
# s
# ,
#
# ,
# ,
#
# w
# h
# i
# c
# h
# ,
#
# T
# h
# e
# ,
#
# w
# a
# i
# t
# ,
#
# s
# t
# a
# f
# f
# ,
#
# w
# a
# s
# ,
#
# p
# o
# l
# i
# t
# e
# ,
#
# a
# n
# d
# ,
#
# a
# ,
#
# f
# e
# w
# ,
#
# m
# i
# n
# u
# t
# e
# s
# ,
#
# w
# a
# l
# k
# ,
#
# f
# r
# o
# m
# ,
#
# a
# l
# l
# ]
#
#
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# l
# a
# s
# t
# ,
#
# n
# i
# g
# h
# t
# ,
#
# w
# a
# s
# ,
#
# a
# m
# a
# z
# i
# n
# g
# ,
#
# !
# ,
#
# T
# h
# e
# ,
#
# u
# s
# -
# ,
#
# G
# r
# e
# e
# n
# ,
#
# p
# a
# s
# t
# a
# ,
#
# w
# i
# t
# h
# ,
#
# s
# h
# r
# i
# m
# p
# ,
#
# w
# a
# s
# ,
#
# G
# r
# e
# e
# n
# ,
#
# p
# a
# s
# t
# a
# ,
#
# w
# i
# t
# h
# ,
#
# s
# h
# r
# i
# m
# p
# ,
#
# w
# a
# s
# ,
#
# s
# u
# p
# e
# r
# b
# ,
#
# g
# r
# e
# a
# t
# ,
#
# A
# s
# i
# a
# n
# ,
#
# f
# l
# a
# v
# o
# r
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# k
# a
# l
# e
# ,
#
# A
# s
# i
# a
# n
# ,
#
# f
# l
# a
# v
# o
# r
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# k
# a
# l
# e
# ,
#
# c
# e
# a
# s
# e
# r
# ,
#
# k
# a
# l
# e
# ,
#
# c
# e
# a
# s
# e
# r
# ,
#
# s
# a
# l
# a
# d
# ,
#
# w
# i
# t
# h
# ,
#
# s
# h
# r
# i
# m
# p
# ,
#
# w
# a
# s
# ,
#
# s
# w
# o
# r
# d
# f
# i
# s
# h
# ,
#
# s
# p
# e
# c
# i
# a
# l
# ,
#
# w
# a
# s
# ,
#
# h
# u
# g
# e
# ,
#
# !
# ,
#
# !
# ,
#
# t
# a
# s
# t
# y
# ,
#
# t
# o
# o
# -
# ,
#
# a
# l
# l
# ,
#
# 5
# ,
#
# o
# f
# ,
#
# u
# s
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# i
# s
# ,
#
# v
# e
# r
# y
# ,
#
# T
# h
# e
# ,
#
# s
# h
# r
# i
# m
# p
# ,
#
# t
# o
# a
# s
# t
# ,
#
# ,
# ,
#
# t
# u
# n
# a
# ,
#
# a
# v
# o
# c
# a
# d
# o
# ,
#
# T
# h
# e
# ,
#
# e
# n
# t
# r
# e
# e
# s
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# w
# e
# r
# e
# ,
#
# l
# o
# v
# e
# d
# ,
#
# w
# e
# ,
#
# h
# a
# d
# ,
#
# w
# e
# r
# e
# ,
#
# l
# o
# v
# e
# d
# ,
#
# b
# y
# ,
#
# a
# l
# l
# ,
#
# T
# h
# e
# ,
#
# k
# a
# l
# e
# ,
#
# c
# e
# a
# s
# e
# r
# ,
#
# s
# a
# l
# a
# d
# ,
#
# w
# i
# t
# h
# ,
#
# s
# h
# r
# i
# m
# p
# ,
#
# T
# h
# e
# ,
#
# B
# r
# u
# s
# s
# e
# l
# ,
#
# s
# p
# r
# o
# u
# t
# s
# ,
#
# w
# e
# r
# e
# ,
#
# r
# e
# a
# l
# l
# y
# ,
#
# t
# a
# s
# t
# y
# ,
#
# u
# s
# ,
#
# e
# n
# j
# o
# y
# e
# d
# ,
#
# a
# l
# l
# ,
#
# w
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# w
# e
# ,
#
# o
# r
# d
# e
# r
# e
# d
# ,
#
# .
# ,
#
# T
# h
# e
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# i
# s
# ,
#
# T
# h
# e
# ,
#
# a
# t
# m
# o
# s
# p
# h
# e
# r
# e
# ,
#
# i
# s
# ,
#
# v
# e
# r
# y
# ,
#
# c
# o
# o
# l
# -
# ,
#
# t
# h
# e
# ,
#
# I
# ,
#
# l
# o
# v
# e
# d
# ,
#
# t
# h
# e
# ,
#
# c
# h
# e
# e
# s
# e
# c
# a
# k
# e
# ,
#
# a
# n
# d
# ,
#
# c
# h
# o
# c
# o
# l
# a
# t
# e
# ,
#
# t
# h
# e
# ,
#
# c
# h
# e
# e
# s
# e
# c
# a
# k
# e
# ,
#
# a
# n
# d
# ,
#
# c
# h
# o
# c
# o
# l
# a
# t
# e
# ,
#
# l
# a
# v
# a
# ,
#
# c
# a
# k
# e
# ]
#
#
# N
# a
# m
# e
# :
#
# w
# o
# r
# d
# _
# s
# e
# g
# m
# e
# n
# t
# s
# _
# u
# n
# p
# a
# c
# k
# e
# d
# ,
#
# d
# t
# y
# p
# e
# :
#
# o
# b
# j
# e
# c
# t

# %%
for i in worst_term['word_segments'][0]:
  for x in i:
    if 'ordered' in list(str(x)):
      print(x)

# %%
dh['term'].iloc[-1]
# Out:
# 'order'

# %%
for i in worst_term['word_segments'][0]:
  if 'service' in list(str(i)):
    print(list(i))

# %%
# dh['term'].iloc[-1] in worst_term['word_segments']
# for i in worst_term[1].iloc[1]:
#   if dh['term'].iloc[-1] in worst_term[1]:
#     print(i)

for i in worst_term['word_segments'][0]:
  for list_of_words in i:
    for y in list_of_words:
      if str(y) == dh['term'].iloc[-1]:
        print(list_of_words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-d2a7a01091e4> in <module>()
#       2 for i in worst_term['word_segments'][0]:
#       3   for list_of_words in i:
# ----> 4     for y in list_of_words:
#       5       if str(y) == dh['term'].iloc[-1]:
#       6         print(list_of_words)
#
# TypeError: 'spacy.tokens.token.Token' object is not iterable
